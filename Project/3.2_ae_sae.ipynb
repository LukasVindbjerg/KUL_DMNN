# %% [markdown]
# #DATA MINING AND NEURAL NETWORKS
# ##Assignment 3.2 - Autoencoders and Stacked Autoencoders
#
# In this file, we will implement two network architectures from scrath: (1) Autoencoders; (2) Stacked Autoencoders.
#
# We will train both networks on the MNIST dataset under reconstruction learning task. All training will be conducted on a single T4 GPU.

# %%
# Please first load your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Please go to the folder with all assignment files
# Please change the following path to your own path
# !cd /content/drive/MyDrive/DMNN/DMNN2023
# Out:
# /bin/bash: line 1: cd: /content/drive/MyDrive/DMNN/DMNN2023: No such file or directory

# %%
# Please go to Edit > Notebook settings > Hardware accelerator > choose "T4 GPU"
# Now check if you have loaded the GPU successfully
# !nvidia-smi
# Out:
# Tue Dec 19 16:51:13 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Autoencoder
# In this section, we implement Linear Autoencoder from scratch and training it on the MNIST dataset. With this autoencoder, we pass input data through an encoder making a compressed representation of the input, and then pass this representation to the following decoder to build the reconstruction data.
# Codes will be implemeneted with ``PyTorch``.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms

# Convert data to torch.FloatTensor
transform = transforms.ToTensor()

# Load the training and test datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 36430232.36it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 110828631.13it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 82014721.57it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7265647.89it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
## Create training and test dataloaders

# How many samples per batch to load
# You can tune the batch size
batch_size = 20

# Prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size,
                                           shuffle = True,
                                           num_workers=0)
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=batch_size,
                                          shuffle = False,
                                          num_workers=0)

# %% [markdown]
# ## Visualize the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy()

# Get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ## Build the Linear Autoencoder
# We now train a linear autoencoder on MINIST dataset.
# Images of original size 28$\times$28 will be flattened into 784-dimensional vectors.
# Note that images from this dataset are already normalized so that the values are between 0 and 1.
# Since the images are normalized between 0 and 1, we need to use a sigmoid activation on the output layer to get values that match this input value range.
#
# The encoder and decoder in the Autoencoder are built with one linear layer where you can tune the dimension of the hidden representation, i.e., ``encoding_dim``, to obtain models with different size.

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the NN architecture
class Autoencoder(nn.Module):
    def __init__(self, encoding_dim):
        super(Autoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Linear(784, encoding_dim)
        # Decoder
        self.decoder = nn.Linear(encoding_dim, 784)

    def forward(self, x):
        # Define feedforward behavior
        # and scale the *output* layer with a sigmoid activation function

        # Pass x into encoder
        out = F.relu(self.encoder(x))
        # Pass out into decoder
        out = torch.sigmoid(self.decoder(out))

        return out

# %%
# Initialize the NN
# You can change the encoding_dim to obtain models with different size
encoding_dim = 64 # 64 ORIGINAL
model = Autoencoder(encoding_dim)

# Send model to GPU
model.cuda()
print(model)
# Out:
# Autoencoder(
#   (encoder): Linear(in_features=784, out_features=64, bias=True)
#   (decoder): Linear(in_features=64, out_features=784, bias=True)
# )

# %% [markdown]
# ## Training on MNIST
# Since we work on reconstruction learning tasks, we do not need the labels here but only the images.
# The loss function should choose the MSE loss for reconstruction.

# %%
# Specify the loss function
criterion = nn.MSELoss()

# We use Adam as the optimizer with a fixed learning rate of 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Number of epochs to train the model
# You can also tune the number of Epochs
n_epochs = 5
# Set model to training mode
model.train()

for epoch in range(n_epochs):
    # Monitor training loss
    train_loss = 0.0

    # Train the model #

    for data in train_loader:
        # _ stands in for labels
        # we do not need labels when conducting reconstruction
        images, _ = data
        # Flatten images and send images to GPU
        images = images.view(images.size(0), -1).cuda()
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()
        # Forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(images)
        # Calculate the loss
        loss = criterion(outputs, images)
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # Perform a single optimization step (parameter update)
        optimizer.step()
        # Update running training loss
        train_loss += loss.item()*images.size(0)

    # Print avg training statistics
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch,
        train_loss
        ))
# Out:
# Epoch: 0 	Training Loss: 0.429866
# Epoch: 1 	Training Loss: 0.142913
# Epoch: 2 	Training Loss: 0.121244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-06e6ab6700a0> in <cell line: 7>()
#      11     # Train the model #
#      12
# ---> 13     for data in train_loader:
#      14         # _ stands in for labels
#      15         # we do not need labels when conducting reconstruction
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     143
#     144         if self.transform is not None:
# --> 145             img = self.transform(img)
#     146
#     147         if self.target_transform is not None:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     135             Tensor: Converted image.
#     136         """
# --> 137         return F.to_tensor(pic)
#     138
#     139     def __repr__(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     172     img = img.permute((2, 0, 1)).contiguous()
#     173     if isinstance(img, torch.ByteTensor):
# --> 174         return img.to(dtype=default_float_dtype).div(255)
#     175     else:
#     176         return img
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation on test set
# We now evaluate the reconstruction results on the test set.
# We plot the original test images and their corresponding reconstruction ones.

# %%
# Obtain one batch of test images
dataiter = iter(test_loader)
images, labels = next(dataiter)

images_flatten = images.view(images.size(0), -1)
# Set model to evaluation mode
model.eval()
# Send model back to CPU
model.cpu()
# Get sample outputs
output = model(images_flatten)
# Prep images for display
images = images.numpy()

# Output is resized into a batch of images
output = output.view(batch_size, 1, 28, 28)
# Use detach when it's an output that requires_grad
output = output.detach().numpy()

# Plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# Input images on top row, reconstructions on bottom
for images, row in zip([images, output], axes):
    for img, ax in zip(images, row):
        ax.imshow(np.squeeze(img), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Stacked Autoencoder
# In this section, we implement the Stacked Autoencoder from scrath and train it on the MNIST dataset.
# The training process is with two steps: (1) each layer is trained separately; (2) the network is trained as a whole.
#
# We first load the dataset as follows:

# %%
import torch
from torch import nn, optim, functional, utils
from torch.nn import BCELoss
from torch.utils.data.dataloader import DataLoader
import torchvision
from torchvision import datasets, utils
from torchvision.datasets import MNIST

import time, os

def get_mnist_loader(batch_size=100, shuffle=True):
    """

    :return: train_loader, test_loader
    """
    train_dataset = MNIST(root='../data',
                          train=True,
                          transform=torchvision.transforms.ToTensor(),
                          download=True)
    test_dataset = MNIST(root='../data',
                         train=False,
                         transform=torchvision.transforms.ToTensor(),
                         download=True)

    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=batch_size,
                                               shuffle=shuffle)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                              batch_size=batch_size,
                                              shuffle=False)
    return train_loader, test_loader

# %% [markdown]
# ## Build the Stacked Autoencoder
# Before building the Stacked Autoencoder, we need to build the Autoencoder layer first.

# %%
class AutoEncoderLayer(nn.Module):
    """
    fully-connected linear layers for stacked autoencoders.
    This module can automatically be trained when training each layer is enabled
    Yes, this is much like the simplest auto-encoder
    """
    def __init__(self, input_dim=None, output_dim=None, SelfTraining=False):
        super(AutoEncoderLayer, self).__init__()
        # If input_dim is None or output_dim is None:
        # raise ValueError
        self.in_features = input_dim
        self.out_features = output_dim
        # Whether to conduct layer-by-layer pre-training, or train the entire network
        self.is_training_self = SelfTraining
        self.encoder = nn.Sequential(
            nn.Linear(self.in_features, self.out_features, bias=True),
            nn.Sigmoid()  # use Sigmoid activation function
        )
        self.decoder = nn.Sequential(
            nn.Linear(self.out_features, self.in_features, bias=True),
            nn.Sigmoid()
        )

    def forward(self, x):
        out = self.encoder(x)
        if self.is_training_self:
            return self.decoder(out)
        else:
            return out

    def lock_grad(self):
        for param in self.parameters():
            param.requires_grad = False

    def acquire_grad(self):
        for param in self.parameters():
            param.requires_grad = True

    @property
    def input_dim(self):
        return self.in_features

    @property
    def output_dim(self):
        return self.out_features

    @property
    def is_training_layer(self):
        return self.is_training_self

    @is_training_layer.setter
    def is_training_layer(self, other: bool):
        self.is_training_self = other


class StackedAutoEncoder(nn.Module):
    """
    Construct the whole network with layers_list
    Stacked autoencoders is generally symmetrical about the middle hidden layer
    """
    def __init__(self, layers_list=None):
        super(StackedAutoEncoder, self).__init__()
        self.layers_list = layers_list
        self.initialize()
        self.encoder_1 = self.layers_list[0]
        self.encoder_2 = self.layers_list[1]
        self.encoder_3 = self.layers_list[2]
        self.encoder_4 = self.layers_list[3]

    def initialize(self):
        for layer in self.layers_list:
            # assert isinstance(layer, AutoEncoderLayer)
            layer.is_training_layer = False

    def forward(self, x):
        out = x
        out = self.encoder_1(out)
        out = self.encoder_2(out)
        out = self.encoder_3(out)
        out = self.encoder_4(out)
        return out

# %% [markdown]
# ## The training function of each layer
# We need to freeze the parameters in the previsou layers when training the current layer.

# %%
def train_layers(layers_list=None, layer=None, epoch=None, validate=True):
    """
    Greedy layer-wise training: when training the i-th layer, freeze the i-1 layer
    :param layers_list:
    :param layer:
    :param epoch:
    :return:
    """
    if torch.cuda.is_available():
        for model in layers_list:
            model.cuda()

    train_loader, test_loader = get_mnist_loader(batch_size=batch_size, shuffle=True)
    optimizer = optim.Adam(layers_list[layer].parameters(), lr=0.001)
    criterion = BCELoss()

    # # Generate/save the original test image --take a batch_size
    # test_data, _ = next(iter(test_loader))
    # torchvision.utils.save_image(test_data, './test_layer_images/real_test_images.png')


    # Train
    for epoch_index in range(epoch):
        sum_loss = 0.

        # Freeze the parameters of all layers before the current layer
        # Layer 0 has no previous layer
        if layer != 0:
            for index in range(layer):
                # In addition to freezing parameters
                # the output return method of the frozen layer must also be set.
                layers_list[index].lock_grad()
                layers_list[index].is_training_layer = False

        for batch_index, (train_data, _) in enumerate(train_loader):
            # Generate input data
            if torch.cuda.is_available():
                train_data = train_data.cuda()  # Put data onto GPU
            out = train_data.view(train_data.size(0), -1)

            # Perform forward calculation on the frozen layers before (layer-1)-th layer
            if layer != 0:
                for l in range(layer):
                    out = layers_list[l](out)

            # Train the layer-th layer
            pred = layers_list[layer](out)

            optimizer.zero_grad()
            loss = criterion(pred, out)
            sum_loss += loss
            loss.backward()
            optimizer.step()
            if (batch_index + 1) % 10 == 0:
                print("Train Layer: {}, Epoch: {}/{}, Iter: {}/{}, Loss: {:.4f}".format(
                    layer, (epoch_index + 1), epoch, (batch_index + 1), len(train_loader), loss
                ))

        # Save reconstructed images after each epoch
        test_data, _ = next(iter(test_loader))
        with torch.no_grad():
            layers_list[layer].eval()
            test_data = test_data.cuda() if torch.cuda.is_available() else test_data
            test_output = layers_list[layer](test_data.view(test_data.size(0), -1))
            torchvision.utils.save_image(test_output.view(batch_size, 1, 28, 28), './test_images/pretrain_layer_{}_epoch_{}_output.png'.format(layer, epoch_index))



        if validate:
          pass
          # with torch.no_grad():
          #     model.eval()
          #     if torch.cuda.is_available():
          #         test_data = test_data.cuda()
          #     x = test_data.view(test_data.size(0), -1)
          #     out = model(x)
          #     loss = criterion(out, x)
          #     print("Test Epoch: {}/{}, Iter: {}/{}, test Loss: {}".format(
          #         epoch_index + 1, epoch, (epoch_index + 1), len(test_loader), loss
          #     ))
          #     image_tensor = out.view(batch_size, 1, 28, 28)
          #     torchvision.utils.save_image(image_tensor, './test_layer_images/test_image_epoch_{}.png'.format(epoch_index))

# %% [markdown]
# ## The training function of the whole network
# Now we unfreeze all the parameters in the network that are previously frozen for the layer training.

# %%
def train_whole(model=None, epoch=50, validate=True):

    print(">> start training whole model")
    if torch.cuda.is_available():
        model.cuda()

    # unfreeze the parameters frozen in pre-training
    for param in model.parameters():
        param.require_grad = True

    train_loader, test_loader = get_mnist_loader(batch_size=batch_size, shuffle=shuffle)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.MSELoss()

    # Generate/save the original test image --take a batch_size
    test_data, _ = next(iter(test_loader))
    torchvision.utils.save_image(test_data, './test_images/real_test_images.png')

    model.train()

    # train
    for epoch_index in range(epoch):
        sum_loss = 0.
        for batch_index, (train_data, _) in enumerate(train_loader):
            if torch.cuda.is_available():
                train_data = train_data.cuda()
            x = train_data.view(train_data.size(0), -1)

            out = model(x)

            optimizer.zero_grad()
            loss = criterion(out, x)
            sum_loss += loss
            loss.backward()
            optimizer.step()

            if (batch_index + 1) % 10 == 0:
                print("Train Whole, Epoch: {}/{}, Iter: {}/{}, Loss: {:.4f}".format(
                    (epoch_index + 1), epoch, (batch_index + 1), len(train_loader), loss
                ))
            if batch_index == len(train_loader) - 1:
                torchvision.utils.save_image(out.view(100, 1, 28, 28), "./test_images/out_{}_{}.png".format(epoch_index, batch_index))

        # evaluate the model for each epoch
        if validate:
            with torch.no_grad():
                model.eval()
                if torch.cuda.is_available():
                    test_data = test_data.cuda()
                x = test_data.view(test_data.size(0), -1)
                out = model(x)
                loss = criterion(out, x)
                print("Test Epoch: {}/{}, Iter: {}/{}, test Loss: {}".format(
                    epoch_index + 1, epoch, (epoch_index + 1), len(test_loader), loss
                ))
                image_tensor = out.view(batch_size, 1, 28, 28)
                torchvision.utils.save_image(image_tensor, './test_images/test_image_epoch_{}.png'.format(epoch_index))

    print("<< end training whole model")

# %% [markdown]
# ## Let's start training!
# The default network is trained with layer epochs 20, whole epochs 50, batch size of 100. You can try to change the hyper-parameters to obtain better reconstruction performance.

# %%
# You can change the hyper-parameters here
num_tranin_layer_epochs = 20
num_tranin_whole_epochs = 50
batch_size = 100
shuffle = True

# %%
import os
if not os.path.exists('test_images'):
    os.mkdir('test_images')
if not os.path.exists('models'):
    os.mkdir('models')
if not os.path.exists('test_images_no_pretrain'):
    os.mkdir('test_images_no_pretrain')
if not os.path.exists('test_images_with_pretrain'):
    os.mkdir('test_images_with_pretrain')

nun_layers = 5
encoder_1 = AutoEncoderLayer(784, 256, SelfTraining=True)
encoder_2 = AutoEncoderLayer(256, 64, SelfTraining=True)
decoder_3 = AutoEncoderLayer(64, 256, SelfTraining=True)
decoder_4 = AutoEncoderLayer(256, 784, SelfTraining=True)
layers_list = [encoder_1, encoder_2, decoder_3, decoder_4]

# SAE_model_no_pretrain = StackedAutoEncoder(layers_list=layers_list)

# Pre-train each layer
for level in range(nun_layers - 1):
    train_layers(layers_list=layers_list, layer=level, epoch=num_tranin_layer_epochs, validate=True)

SAE_model_with_pretrain = StackedAutoEncoder(layers_list=layers_list)
train_whole(model=SAE_model_with_pretrain, epoch=num_tranin_whole_epochs, validate=True)

# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
torch.save(SAE_model_with_pretrain, './models/sae_model_with_pretrain_original.pt')

# FIRST : Save images from both models:
# test_data, _ = next(iter(test_loader))
# torchvision.utils.save_image(test_data, './test_images/real_test_images.png')

# with torch.no_grad():
#     SAE_model_no_pretrain.eval()
#     if torch.cuda.is_available():
#         test_data = test_data.cuda()
#     x = test_data.view(test_data.size(0), -1)
#     out = SAE_model_no_pretrain(x)
#     loss = criterion(out, x)

#     image_tensor = out.view(20, 1, 28, 28)
#     torchvision.utils.save_image(image_tensor, './test_layer_images/manual_test_no_pretrain.png')

# with torch.no_grad():
#     SAE_model_with_pretrain.eval()
#     if torch.cuda.is_available():
#         test_data = test_data.cuda()
#     x = test_data.view(test_data.size(0), -1)
#     out = SAE_model_with_pretrain(x)
#     loss = criterion(out, x)

#     image_tensor = out.view(20, 1, 28, 28)
#     torchvision.utils.save_image(image_tensor, './test_layer_images/manual_test_with_pretrain.png')

# # Training the two models:
# train_whole(model=SAE_model_no_pretrain, epoch=num_tranin_whole_epochs, validate=True)
# torch.save(SAE_model_no_pretrain, './models/sae_model_no_pretrain.pt')

# train_whole(model=SAE_model_with_pretrain, epoch=num_tranin_whole_epochs, validate=True)
# torch.save(SAE_model_with_pretrain, './models/sae_model_with_pretrain.pt')

# Training the network as a whole
# SAE_model = StackedAutoEncoder(layers_list=layers_list)
# train_whole(model=SAE_model, epoch=num_tranin_whole_epochs, validate=True)

# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
# torch.save(SAE_model, './models/sae_model.pt')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 202593894.48it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 60146819.18it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 15814583.66it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 21238047.68it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Train Layer: 0, Epoch: 1/20, Iter: 10/600, Loss: 0.3875
# Train Layer: 0, Epoch: 1/20, Iter: 20/600, Loss: 0.2871
# Train Layer: 0, Epoch: 1/20, Iter: 30/600, Loss: 0.2678
# Train Layer: 0, Epoch: 1/20, Iter: 40/600, Loss: 0.2553
# Train Layer: 0, Epoch: 1/20, Iter: 50/600, Loss: 0.2679
# Train Layer: 0, Epoch: 1/20, Iter: 60/600, Loss: 0.2672
# Train Layer: 0, Epoch: 1/20, Iter: 70/600, Loss: 0.2520
# Train Layer: 0, Epoch: 1/20, Iter: 80/600, Loss: 0.2543
# Train Layer: 0, Epoch: 1/20, Iter: 90/600, Loss: 0.2397
# Train Layer: 0, Epoch: 1/20, Iter: 100/600, Loss: 0.2465
# Train Layer: 0, Epoch: 1/20, Iter: 110/600, Loss: 0.2407
# Train Layer: 0, Epoch: 1/20, Iter: 120/600, Loss: 0.2324
# Train Layer: 0, Epoch: 1/20, Iter: 130/600, Loss: 0.2291
# Train Layer: 0, Epoch: 1/20, Iter: 140/600, Loss: 0.2208
# Train Layer: 0, Epoch: 1/20, Iter: 150/600, Loss: 0.2289
# Train Layer: 0, Epoch: 1/20, Iter: 160/600, Loss: 0.2275
# Train Layer: 0, Epoch: 1/20, Iter: 170/600, Loss: 0.2048
# Train Layer: 0, Epoch: 1/20, Iter: 180/600, Loss: 0.2110
# Train Layer: 0, Epoch: 1/20, Iter: 190/600, Loss: 0.2045
# Train Layer: 0, Epoch: 1/20, Iter: 200/600, Loss: 0.2040
# Train Layer: 0, Epoch: 1/20, Iter: 210/600, Loss: 0.2069
# Train Layer: 0, Epoch: 1/20, Iter: 220/600, Loss: 0.1990
# Train Layer: 0, Epoch: 1/20, Iter: 230/600, Loss: 0.2005
# Train Layer: 0, Epoch: 1/20, Iter: 240/600, Loss: 0.1975
# Train Layer: 0, Epoch: 1/20, Iter: 250/600, Loss: 0.1876
# Train Layer: 0, Epoch: 1/20, Iter: 260/600, Loss: 0.1901
# Train Layer: 0, Epoch: 1/20, Iter: 270/600, Loss: 0.1857
# Train Layer: 0, Epoch: 1/20, Iter: 280/600, Loss: 0.1830
# Train Layer: 0, Epoch: 1/20, Iter: 290/600, Loss: 0.1847
# Train Layer: 0, Epoch: 1/20, Iter: 300/600, Loss: 0.1855
# Train Layer: 0, Epoch: 1/20, Iter: 310/600, Loss: 0.1732
# Train Layer: 0, Epoch: 1/20, Iter: 320/600, Loss: 0.1672
# Train Layer: 0, Epoch: 1/20, Iter: 330/600, Loss: 0.1770
# Train Layer: 0, Epoch: 1/20, Iter: 340/600, Loss: 0.1716
# Train Layer: 0, Epoch: 1/20, Iter: 350/600, Loss: 0.1813
# Train Layer: 0, Epoch: 1/20, Iter: 360/600, Loss: 0.1663
# Train Layer: 0, Epoch: 1/20, Iter: 370/600, Loss: 0.1722
# Train Layer: 0, Epoch: 1/20, Iter: 380/600, Loss: 0.1751
# Train Layer: 0, Epoch: 1/20, Iter: 390/600, Loss: 0.1686
# Train Layer: 0, Epoch: 1/20, Iter: 400/600, Loss: 0.1626
# Train Layer: 0, Epoch: 1/20, Iter: 410/600, Loss: 0.1593
# Train Layer: 0, Epoch: 1/20, Iter: 420/600, Loss: 0.1639
# Train Layer: 0, Epoch: 1/20, Iter: 430/600, Loss: 0.1591
# Train Layer: 0, Epoch: 1/20, Iter: 440/600, Loss: 0.1549
# Train Layer: 0, Epoch: 1/20, Iter: 450/600, Loss: 0.1561
# Train Layer: 0, Epoch: 1/20, Iter: 460/600, Loss: 0.1506
# Train Layer: 0, Epoch: 1/20, Iter: 470/600, Loss: 0.1526
# Train Layer: 0, Epoch: 1/20, Iter: 480/600, Loss: 0.1511
# Train Layer: 0, Epoch: 1/20, Iter: 490/600, Loss: 0.1557
# Train Layer: 0, Epoch: 1/20, Iter: 500/600, Loss: 0.1504
# Train Layer: 0, Epoch: 1/20, Iter: 510/600, Loss: 0.1476
# Train Layer: 0, Epoch: 1/20, Iter: 520/600, Loss: 0.1545
# Train Layer: 0, Epoch: 1/20, Iter: 530/600, Loss: 0.1466
# Train Layer: 0, Epoch: 1/20, Iter: 540/600, Loss: 0.1421
# Train Layer: 0, Epoch: 1/20, Iter: 550/600, Loss: 0.1409
# Train Layer: 0, Epoch: 1/20, Iter: 560/600, Loss: 0.1509
# Train Layer: 0, Epoch: 1/20, Iter: 570/600, Loss: 0.1524
# Train Layer: 0, Epoch: 1/20, Iter: 580/600, Loss: 0.1450
# Train Layer: 0, Epoch: 1/20, Iter: 590/600, Loss: 0.1363
# Train Layer: 0, Epoch: 1/20, Iter: 600/600, Loss: 0.1451
# Train Layer: 0, Epoch: 2/20, Iter: 10/600, Loss: 0.1444
# Train Layer: 0, Epoch: 2/20, Iter: 20/600, Loss: 0.1431
# Train Layer: 0, Epoch: 2/20, Iter: 30/600, Loss: 0.1436
# Train Layer: 0, Epoch: 2/20, Iter: 40/600, Loss: 0.1407
# Train Layer: 0, Epoch: 2/20, Iter: 50/600, Loss: 0.1438
# Train Layer: 0, Epoch: 2/20, Iter: 60/600, Loss: 0.1344
# Train Layer: 0, Epoch: 2/20, Iter: 70/600, Loss: 0.1304
# Train Layer: 0, Epoch: 2/20, Iter: 80/600, Loss: 0.1381
# Train Layer: 0, Epoch: 2/20, Iter: 90/600, Loss: 0.1315
# Train Layer: 0, Epoch: 2/20, Iter: 100/600, Loss: 0.1332
# Train Layer: 0, Epoch: 2/20, Iter: 110/600, Loss: 0.1353
# Train Layer: 0, Epoch: 2/20, Iter: 120/600, Loss: 0.1298
# Train Layer: 0, Epoch: 2/20, Iter: 130/600, Loss: 0.1314
# Train Layer: 0, Epoch: 2/20, Iter: 140/600, Loss: 0.1303
# Train Layer: 0, Epoch: 2/20, Iter: 150/600, Loss: 0.1272
# Train Layer: 0, Epoch: 2/20, Iter: 160/600, Loss: 0.1241
# Train Layer: 0, Epoch: 2/20, Iter: 170/600, Loss: 0.1247
# Train Layer: 0, Epoch: 2/20, Iter: 180/600, Loss: 0.1259
# Train Layer: 0, Epoch: 2/20, Iter: 190/600, Loss: 0.1261
# Train Layer: 0, Epoch: 2/20, Iter: 200/600, Loss: 0.1304
# Train Layer: 0, Epoch: 2/20, Iter: 210/600, Loss: 0.1223
# Train Layer: 0, Epoch: 2/20, Iter: 220/600, Loss: 0.1245
# Train Layer: 0, Epoch: 2/20, Iter: 230/600, Loss: 0.1238
# Train Layer: 0, Epoch: 2/20, Iter: 240/600, Loss: 0.1184
# Train Layer: 0, Epoch: 2/20, Iter: 250/600, Loss: 0.1219
# Train Layer: 0, Epoch: 2/20, Iter: 260/600, Loss: 0.1216
# Train Layer: 0, Epoch: 2/20, Iter: 270/600, Loss: 0.1205
# Train Layer: 0, Epoch: 2/20, Iter: 280/600, Loss: 0.1177
# Train Layer: 0, Epoch: 2/20, Iter: 290/600, Loss: 0.1215
# Train Layer: 0, Epoch: 2/20, Iter: 300/600, Loss: 0.1151
# Train Layer: 0, Epoch: 2/20, Iter: 310/600, Loss: 0.1221
# Train Layer: 0, Epoch: 2/20, Iter: 320/600, Loss: 0.1150
# Train Layer: 0, Epoch: 2/20, Iter: 330/600, Loss: 0.1178
# Train Layer: 0, Epoch: 2/20, Iter: 340/600, Loss: 0.1096
# Train Layer: 0, Epoch: 2/20, Iter: 350/600, Loss: 0.1157
# Train Layer: 0, Epoch: 2/20, Iter: 360/600, Loss: 0.1103
# Train Layer: 0, Epoch: 2/20, Iter: 370/600, Loss: 0.1134
# Train Layer: 0, Epoch: 2/20, Iter: 380/600, Loss: 0.1182
# Train Layer: 0, Epoch: 2/20, Iter: 390/600, Loss: 0.1131
# Train Layer: 0, Epoch: 2/20, Iter: 400/600, Loss: 0.1134
# Train Layer: 0, Epoch: 2/20, Iter: 410/600, Loss: 0.1138
# Train Layer: 0, Epoch: 2/20, Iter: 420/600, Loss: 0.1151
# Train Layer: 0, Epoch: 2/20, Iter: 430/600, Loss: 0.1137
# Train Layer: 0, Epoch: 2/20, Iter: 440/600, Loss: 0.1110
# Train Layer: 0, Epoch: 2/20, Iter: 450/600, Loss: 0.1113
# Train Layer: 0, Epoch: 2/20, Iter: 460/600, Loss: 0.1072
# Train Layer: 0, Epoch: 2/20, Iter: 470/600, Loss: 0.1117
# Train Layer: 0, Epoch: 2/20, Iter: 480/600, Loss: 0.1176
# Train Layer: 0, Epoch: 2/20, Iter: 490/600, Loss: 0.1128
# Train Layer: 0, Epoch: 2/20, Iter: 500/600, Loss: 0.1091
# Train Layer: 0, Epoch: 2/20, Iter: 510/600, Loss: 0.1103
# Train Layer: 0, Epoch: 2/20, Iter: 520/600, Loss: 0.1106
# Train Layer: 0, Epoch: 2/20, Iter: 530/600, Loss: 0.1094
# Train Layer: 0, Epoch: 2/20, Iter: 540/600, Loss: 0.1062
# Train Layer: 0, Epoch: 2/20, Iter: 550/600, Loss: 0.1096
# Train Layer: 0, Epoch: 2/20, Iter: 560/600, Loss: 0.1025
# Train Layer: 0, Epoch: 2/20, Iter: 570/600, Loss: 0.1044
# Train Layer: 0, Epoch: 2/20, Iter: 580/600, Loss: 0.1071
# Train Layer: 0, Epoch: 2/20, Iter: 590/600, Loss: 0.1045
# Train Layer: 0, Epoch: 2/20, Iter: 600/600, Loss: 0.1132
# Train Layer: 0, Epoch: 3/20, Iter: 10/600, Loss: 0.1064
# Train Layer: 0, Epoch: 3/20, Iter: 20/600, Loss: 0.0992
# Train Layer: 0, Epoch: 3/20, Iter: 30/600, Loss: 0.1004
# Train Layer: 0, Epoch: 3/20, Iter: 40/600, Loss: 0.1031
# Train Layer: 0, Epoch: 3/20, Iter: 50/600, Loss: 0.1020
# Train Layer: 0, Epoch: 3/20, Iter: 60/600, Loss: 0.1009
# Train Layer: 0, Epoch: 3/20, Iter: 70/600, Loss: 0.1054
# Train Layer: 0, Epoch: 3/20, Iter: 80/600, Loss: 0.0954
# Train Layer: 0, Epoch: 3/20, Iter: 90/600, Loss: 0.1077
# Train Layer: 0, Epoch: 3/20, Iter: 100/600, Loss: 0.1015
# Train Layer: 0, Epoch: 3/20, Iter: 110/600, Loss: 0.0954
# Train Layer: 0, Epoch: 3/20, Iter: 120/600, Loss: 0.0980
# Train Layer: 0, Epoch: 3/20, Iter: 130/600, Loss: 0.1038
# Train Layer: 0, Epoch: 3/20, Iter: 140/600, Loss: 0.0999
# Train Layer: 0, Epoch: 3/20, Iter: 150/600, Loss: 0.0988
# Train Layer: 0, Epoch: 3/20, Iter: 160/600, Loss: 0.0969
# Train Layer: 0, Epoch: 3/20, Iter: 170/600, Loss: 0.0961
# Train Layer: 0, Epoch: 3/20, Iter: 180/600, Loss: 0.1002
# Train Layer: 0, Epoch: 3/20, Iter: 190/600, Loss: 0.0959
# Train Layer: 0, Epoch: 3/20, Iter: 200/600, Loss: 0.0982
# Train Layer: 0, Epoch: 3/20, Iter: 210/600, Loss: 0.0946
# Train Layer: 0, Epoch: 3/20, Iter: 220/600, Loss: 0.0969
# Train Layer: 0, Epoch: 3/20, Iter: 230/600, Loss: 0.0912
# Train Layer: 0, Epoch: 3/20, Iter: 240/600, Loss: 0.0977
# Train Layer: 0, Epoch: 3/20, Iter: 250/600, Loss: 0.0978
# Train Layer: 0, Epoch: 3/20, Iter: 260/600, Loss: 0.0922
# Train Layer: 0, Epoch: 3/20, Iter: 270/600, Loss: 0.1019
# Train Layer: 0, Epoch: 3/20, Iter: 280/600, Loss: 0.0955
# Train Layer: 0, Epoch: 3/20, Iter: 290/600, Loss: 0.0999
# Train Layer: 0, Epoch: 3/20, Iter: 300/600, Loss: 0.0930
# Train Layer: 0, Epoch: 3/20, Iter: 310/600, Loss: 0.0963
# Train Layer: 0, Epoch: 3/20, Iter: 320/600, Loss: 0.0921
# Train Layer: 0, Epoch: 3/20, Iter: 330/600, Loss: 0.0971
# Train Layer: 0, Epoch: 3/20, Iter: 340/600, Loss: 0.0962
# Train Layer: 0, Epoch: 3/20, Iter: 350/600, Loss: 0.0921
# Train Layer: 0, Epoch: 3/20, Iter: 360/600, Loss: 0.0971
# Train Layer: 0, Epoch: 3/20, Iter: 370/600, Loss: 0.0932
# Train Layer: 0, Epoch: 3/20, Iter: 380/600, Loss: 0.0968
# Train Layer: 0, Epoch: 3/20, Iter: 390/600, Loss: 0.0957
# Train Layer: 0, Epoch: 3/20, Iter: 400/600, Loss: 0.0924
# Train Layer: 0, Epoch: 3/20, Iter: 410/600, Loss: 0.0928
# Train Layer: 0, Epoch: 3/20, Iter: 420/600, Loss: 0.0874
# Train Layer: 0, Epoch: 3/20, Iter: 430/600, Loss: 0.0941
# Train Layer: 0, Epoch: 3/20, Iter: 440/600, Loss: 0.0915
# Train Layer: 0, Epoch: 3/20, Iter: 450/600, Loss: 0.0923
# Train Layer: 0, Epoch: 3/20, Iter: 460/600, Loss: 0.0936
# Train Layer: 0, Epoch: 3/20, Iter: 470/600, Loss: 0.0944
# Train Layer: 0, Epoch: 3/20, Iter: 480/600, Loss: 0.0921
# Train Layer: 0, Epoch: 3/20, Iter: 490/600, Loss: 0.0945
# Train Layer: 0, Epoch: 3/20, Iter: 500/600, Loss: 0.0893
# Train Layer: 0, Epoch: 3/20, Iter: 510/600, Loss: 0.0869
# Train Layer: 0, Epoch: 3/20, Iter: 520/600, Loss: 0.0912
# Train Layer: 0, Epoch: 3/20, Iter: 530/600, Loss: 0.0870
# Train Layer: 0, Epoch: 3/20, Iter: 540/600, Loss: 0.0936
# Train Layer: 0, Epoch: 3/20, Iter: 550/600, Loss: 0.0898
# Train Layer: 0, Epoch: 3/20, Iter: 560/600, Loss: 0.0907
# Train Layer: 0, Epoch: 3/20, Iter: 570/600, Loss: 0.0884
# Train Layer: 0, Epoch: 3/20, Iter: 580/600, Loss: 0.0896
# Train Layer: 0, Epoch: 3/20, Iter: 590/600, Loss: 0.0910
# Train Layer: 0, Epoch: 3/20, Iter: 600/600, Loss: 0.0901
# Train Layer: 0, Epoch: 4/20, Iter: 10/600, Loss: 0.0886
# Train Layer: 0, Epoch: 4/20, Iter: 20/600, Loss: 0.0915
# Train Layer: 0, Epoch: 4/20, Iter: 30/600, Loss: 0.0905
# Train Layer: 0, Epoch: 4/20, Iter: 40/600, Loss: 0.0867
# Train Layer: 0, Epoch: 4/20, Iter: 50/600, Loss: 0.0881
# Train Layer: 0, Epoch: 4/20, Iter: 60/600, Loss: 0.0882
# Train Layer: 0, Epoch: 4/20, Iter: 70/600, Loss: 0.0868
# Train Layer: 0, Epoch: 4/20, Iter: 80/600, Loss: 0.0876
# Train Layer: 0, Epoch: 4/20, Iter: 90/600, Loss: 0.0887
# Train Layer: 0, Epoch: 4/20, Iter: 100/600, Loss: 0.0861
# Train Layer: 0, Epoch: 4/20, Iter: 110/600, Loss: 0.0872
# Train Layer: 0, Epoch: 4/20, Iter: 120/600, Loss: 0.0908
# Train Layer: 0, Epoch: 4/20, Iter: 130/600, Loss: 0.0847
# Train Layer: 0, Epoch: 4/20, Iter: 140/600, Loss: 0.0913
# Train Layer: 0, Epoch: 4/20, Iter: 150/600, Loss: 0.0900
# Train Layer: 0, Epoch: 4/20, Iter: 160/600, Loss: 0.0889
# Train Layer: 0, Epoch: 4/20, Iter: 170/600, Loss: 0.0859
# Train Layer: 0, Epoch: 4/20, Iter: 180/600, Loss: 0.0876
# Train Layer: 0, Epoch: 4/20, Iter: 190/600, Loss: 0.0848
# Train Layer: 0, Epoch: 4/20, Iter: 200/600, Loss: 0.0884
# Train Layer: 0, Epoch: 4/20, Iter: 210/600, Loss: 0.0841
# Train Layer: 0, Epoch: 4/20, Iter: 220/600, Loss: 0.0879
# Train Layer: 0, Epoch: 4/20, Iter: 230/600, Loss: 0.0895
# Train Layer: 0, Epoch: 4/20, Iter: 240/600, Loss: 0.0861
# Train Layer: 0, Epoch: 4/20, Iter: 250/600, Loss: 0.0852
# Train Layer: 0, Epoch: 4/20, Iter: 260/600, Loss: 0.0829
# Train Layer: 0, Epoch: 4/20, Iter: 270/600, Loss: 0.0813
# Train Layer: 0, Epoch: 4/20, Iter: 280/600, Loss: 0.0858
# Train Layer: 0, Epoch: 4/20, Iter: 290/600, Loss: 0.0887
# Train Layer: 0, Epoch: 4/20, Iter: 300/600, Loss: 0.0843
# Train Layer: 0, Epoch: 4/20, Iter: 310/600, Loss: 0.0834
# Train Layer: 0, Epoch: 4/20, Iter: 320/600, Loss: 0.0901
# Train Layer: 0, Epoch: 4/20, Iter: 330/600, Loss: 0.0823
# Train Layer: 0, Epoch: 4/20, Iter: 340/600, Loss: 0.0890
# Train Layer: 0, Epoch: 4/20, Iter: 350/600, Loss: 0.0822
# Train Layer: 0, Epoch: 4/20, Iter: 360/600, Loss: 0.0875
# Train Layer: 0, Epoch: 4/20, Iter: 370/600, Loss: 0.0869
# Train Layer: 0, Epoch: 4/20, Iter: 380/600, Loss: 0.0868
# Train Layer: 0, Epoch: 4/20, Iter: 390/600, Loss: 0.0818
# Train Layer: 0, Epoch: 4/20, Iter: 400/600, Loss: 0.0802
# Train Layer: 0, Epoch: 4/20, Iter: 410/600, Loss: 0.0830
# Train Layer: 0, Epoch: 4/20, Iter: 420/600, Loss: 0.0846
# Train Layer: 0, Epoch: 4/20, Iter: 430/600, Loss: 0.0808
# Train Layer: 0, Epoch: 4/20, Iter: 440/600, Loss: 0.0838
# Train Layer: 0, Epoch: 4/20, Iter: 450/600, Loss: 0.0818
# Train Layer: 0, Epoch: 4/20, Iter: 460/600, Loss: 0.0830
# Train Layer: 0, Epoch: 4/20, Iter: 470/600, Loss: 0.0855
# Train Layer: 0, Epoch: 4/20, Iter: 480/600, Loss: 0.0817
# Train Layer: 0, Epoch: 4/20, Iter: 490/600, Loss: 0.0816
# Train Layer: 0, Epoch: 4/20, Iter: 500/600, Loss: 0.0825
# Train Layer: 0, Epoch: 4/20, Iter: 510/600, Loss: 0.0800
# Train Layer: 0, Epoch: 4/20, Iter: 520/600, Loss: 0.0803
# Train Layer: 0, Epoch: 4/20, Iter: 530/600, Loss: 0.0858
# Train Layer: 0, Epoch: 4/20, Iter: 540/600, Loss: 0.0817
# Train Layer: 0, Epoch: 4/20, Iter: 550/600, Loss: 0.0840
# Train Layer: 0, Epoch: 4/20, Iter: 560/600, Loss: 0.0857
# Train Layer: 0, Epoch: 4/20, Iter: 570/600, Loss: 0.0860
# Train Layer: 0, Epoch: 4/20, Iter: 580/600, Loss: 0.0832
# Train Layer: 0, Epoch: 4/20, Iter: 590/600, Loss: 0.0814
# Train Layer: 0, Epoch: 4/20, Iter: 600/600, Loss: 0.0806
# Train Layer: 0, Epoch: 5/20, Iter: 10/600, Loss: 0.0876
# Train Layer: 0, Epoch: 5/20, Iter: 20/600, Loss: 0.0794
# Train Layer: 0, Epoch: 5/20, Iter: 30/600, Loss: 0.0787
# Train Layer: 0, Epoch: 5/20, Iter: 40/600, Loss: 0.0823
# Train Layer: 0, Epoch: 5/20, Iter: 50/600, Loss: 0.0780
# Train Layer: 0, Epoch: 5/20, Iter: 60/600, Loss: 0.0845
# Train Layer: 0, Epoch: 5/20, Iter: 70/600, Loss: 0.0851
# Train Layer: 0, Epoch: 5/20, Iter: 80/600, Loss: 0.0815
# Train Layer: 0, Epoch: 5/20, Iter: 90/600, Loss: 0.0798
# Train Layer: 0, Epoch: 5/20, Iter: 100/600, Loss: 0.0825
# Train Layer: 0, Epoch: 5/20, Iter: 110/600, Loss: 0.0810
# Train Layer: 0, Epoch: 5/20, Iter: 120/600, Loss: 0.0825
# Train Layer: 0, Epoch: 5/20, Iter: 130/600, Loss: 0.0832
# Train Layer: 0, Epoch: 5/20, Iter: 140/600, Loss: 0.0821
# Train Layer: 0, Epoch: 5/20, Iter: 150/600, Loss: 0.0845
# Train Layer: 0, Epoch: 5/20, Iter: 160/600, Loss: 0.0786
# Train Layer: 0, Epoch: 5/20, Iter: 170/600, Loss: 0.0796
# Train Layer: 0, Epoch: 5/20, Iter: 180/600, Loss: 0.0798
# Train Layer: 0, Epoch: 5/20, Iter: 190/600, Loss: 0.0803
# Train Layer: 0, Epoch: 5/20, Iter: 200/600, Loss: 0.0826
# Train Layer: 0, Epoch: 5/20, Iter: 210/600, Loss: 0.0828
# Train Layer: 0, Epoch: 5/20, Iter: 220/600, Loss: 0.0793
# Train Layer: 0, Epoch: 5/20, Iter: 230/600, Loss: 0.0781
# Train Layer: 0, Epoch: 5/20, Iter: 240/600, Loss: 0.0831
# Train Layer: 0, Epoch: 5/20, Iter: 250/600, Loss: 0.0813
# Train Layer: 0, Epoch: 5/20, Iter: 260/600, Loss: 0.0778
# Train Layer: 0, Epoch: 5/20, Iter: 270/600, Loss: 0.0783
# Train Layer: 0, Epoch: 5/20, Iter: 280/600, Loss: 0.0766
# Train Layer: 0, Epoch: 5/20, Iter: 290/600, Loss: 0.0753
# Train Layer: 0, Epoch: 5/20, Iter: 300/600, Loss: 0.0766
# Train Layer: 0, Epoch: 5/20, Iter: 310/600, Loss: 0.0786
# Train Layer: 0, Epoch: 5/20, Iter: 320/600, Loss: 0.0827
# Train Layer: 0, Epoch: 5/20, Iter: 330/600, Loss: 0.0799
# Train Layer: 0, Epoch: 5/20, Iter: 340/600, Loss: 0.0801
# Train Layer: 0, Epoch: 5/20, Iter: 350/600, Loss: 0.0795
# Train Layer: 0, Epoch: 5/20, Iter: 360/600, Loss: 0.0846
# Train Layer: 0, Epoch: 5/20, Iter: 370/600, Loss: 0.0799
# Train Layer: 0, Epoch: 5/20, Iter: 380/600, Loss: 0.0819
# Train Layer: 0, Epoch: 5/20, Iter: 390/600, Loss: 0.0807
# Train Layer: 0, Epoch: 5/20, Iter: 400/600, Loss: 0.0771
# Train Layer: 0, Epoch: 5/20, Iter: 410/600, Loss: 0.0778
# Train Layer: 0, Epoch: 5/20, Iter: 420/600, Loss: 0.0803
# Train Layer: 0, Epoch: 5/20, Iter: 430/600, Loss: 0.0817
# Train Layer: 0, Epoch: 5/20, Iter: 440/600, Loss: 0.0808
# Train Layer: 0, Epoch: 5/20, Iter: 450/600, Loss: 0.0822
# Train Layer: 0, Epoch: 5/20, Iter: 460/600, Loss: 0.0760
# Train Layer: 0, Epoch: 5/20, Iter: 470/600, Loss: 0.0821
# Train Layer: 0, Epoch: 5/20, Iter: 480/600, Loss: 0.0770
# Train Layer: 0, Epoch: 5/20, Iter: 490/600, Loss: 0.0806
# Train Layer: 0, Epoch: 5/20, Iter: 500/600, Loss: 0.0792
# Train Layer: 0, Epoch: 5/20, Iter: 510/600, Loss: 0.0794
# Train Layer: 0, Epoch: 5/20, Iter: 520/600, Loss: 0.0753
# Train Layer: 0, Epoch: 5/20, Iter: 530/600, Loss: 0.0797
# Train Layer: 0, Epoch: 5/20, Iter: 540/600, Loss: 0.0774
# Train Layer: 0, Epoch: 5/20, Iter: 550/600, Loss: 0.0760
# Train Layer: 0, Epoch: 5/20, Iter: 560/600, Loss: 0.0776
# Train Layer: 0, Epoch: 5/20, Iter: 570/600, Loss: 0.0809
# Train Layer: 0, Epoch: 5/20, Iter: 580/600, Loss: 0.0752
# Train Layer: 0, Epoch: 5/20, Iter: 590/600, Loss: 0.0778
# Train Layer: 0, Epoch: 5/20, Iter: 600/600, Loss: 0.0781
# Train Layer: 0, Epoch: 6/20, Iter: 10/600, Loss: 0.0804
# Train Layer: 0, Epoch: 6/20, Iter: 20/600, Loss: 0.0742
# Train Layer: 0, Epoch: 6/20, Iter: 30/600, Loss: 0.0819
# Train Layer: 0, Epoch: 6/20, Iter: 40/600, Loss: 0.0777
# Train Layer: 0, Epoch: 6/20, Iter: 50/600, Loss: 0.0779
# Train Layer: 0, Epoch: 6/20, Iter: 60/600, Loss: 0.0787
# Train Layer: 0, Epoch: 6/20, Iter: 70/600, Loss: 0.0813
# Train Layer: 0, Epoch: 6/20, Iter: 80/600, Loss: 0.0768
# Train Layer: 0, Epoch: 6/20, Iter: 90/600, Loss: 0.0791
# Train Layer: 0, Epoch: 6/20, Iter: 100/600, Loss: 0.0760
# Train Layer: 0, Epoch: 6/20, Iter: 110/600, Loss: 0.0771
# Train Layer: 0, Epoch: 6/20, Iter: 120/600, Loss: 0.0811
# Train Layer: 0, Epoch: 6/20, Iter: 130/600, Loss: 0.0736
# Train Layer: 0, Epoch: 6/20, Iter: 140/600, Loss: 0.0763
# Train Layer: 0, Epoch: 6/20, Iter: 150/600, Loss: 0.0750
# Train Layer: 0, Epoch: 6/20, Iter: 160/600, Loss: 0.0774
# Train Layer: 0, Epoch: 6/20, Iter: 170/600, Loss: 0.0789
# Train Layer: 0, Epoch: 6/20, Iter: 180/600, Loss: 0.0797
# Train Layer: 0, Epoch: 6/20, Iter: 190/600, Loss: 0.0740
# Train Layer: 0, Epoch: 6/20, Iter: 200/600, Loss: 0.0749
# Train Layer: 0, Epoch: 6/20, Iter: 210/600, Loss: 0.0738
# Train Layer: 0, Epoch: 6/20, Iter: 220/600, Loss: 0.0803
# Train Layer: 0, Epoch: 6/20, Iter: 230/600, Loss: 0.0772
# Train Layer: 0, Epoch: 6/20, Iter: 240/600, Loss: 0.0771
# Train Layer: 0, Epoch: 6/20, Iter: 250/600, Loss: 0.0789
# Train Layer: 0, Epoch: 6/20, Iter: 260/600, Loss: 0.0763
# Train Layer: 0, Epoch: 6/20, Iter: 270/600, Loss: 0.0780
# Train Layer: 0, Epoch: 6/20, Iter: 280/600, Loss: 0.0747
# Train Layer: 0, Epoch: 6/20, Iter: 290/600, Loss: 0.0749
# Train Layer: 0, Epoch: 6/20, Iter: 300/600, Loss: 0.0772
# Train Layer: 0, Epoch: 6/20, Iter: 310/600, Loss: 0.0747
# Train Layer: 0, Epoch: 6/20, Iter: 320/600, Loss: 0.0778
# Train Layer: 0, Epoch: 6/20, Iter: 330/600, Loss: 0.0749
# Train Layer: 0, Epoch: 6/20, Iter: 340/600, Loss: 0.0779
# Train Layer: 0, Epoch: 6/20, Iter: 350/600, Loss: 0.0758
# Train Layer: 0, Epoch: 6/20, Iter: 360/600, Loss: 0.0773
# Train Layer: 0, Epoch: 6/20, Iter: 370/600, Loss: 0.0746
# Train Layer: 0, Epoch: 6/20, Iter: 380/600, Loss: 0.0773
# Train Layer: 0, Epoch: 6/20, Iter: 390/600, Loss: 0.0764
# Train Layer: 0, Epoch: 6/20, Iter: 400/600, Loss: 0.0749
# Train Layer: 0, Epoch: 6/20, Iter: 410/600, Loss: 0.0775
# Train Layer: 0, Epoch: 6/20, Iter: 420/600, Loss: 0.0771
# Train Layer: 0, Epoch: 6/20, Iter: 430/600, Loss: 0.0769
# Train Layer: 0, Epoch: 6/20, Iter: 440/600, Loss: 0.0776
# Train Layer: 0, Epoch: 6/20, Iter: 450/600, Loss: 0.0771
# Train Layer: 0, Epoch: 6/20, Iter: 460/600, Loss: 0.0738
# Train Layer: 0, Epoch: 6/20, Iter: 470/600, Loss: 0.0793
# Train Layer: 0, Epoch: 6/20, Iter: 480/600, Loss: 0.0735
# Train Layer: 0, Epoch: 6/20, Iter: 490/600, Loss: 0.0788
# Train Layer: 0, Epoch: 6/20, Iter: 500/600, Loss: 0.0758
# Train Layer: 0, Epoch: 6/20, Iter: 510/600, Loss: 0.0772
# Train Layer: 0, Epoch: 6/20, Iter: 520/600, Loss: 0.0806
# Train Layer: 0, Epoch: 6/20, Iter: 530/600, Loss: 0.0758
# Train Layer: 0, Epoch: 6/20, Iter: 540/600, Loss: 0.0755
# Train Layer: 0, Epoch: 6/20, Iter: 550/600, Loss: 0.0766
# Train Layer: 0, Epoch: 6/20, Iter: 560/600, Loss: 0.0763
# Train Layer: 0, Epoch: 6/20, Iter: 570/600, Loss: 0.0770
# Train Layer: 0, Epoch: 6/20, Iter: 580/600, Loss: 0.0772
# Train Layer: 0, Epoch: 6/20, Iter: 590/600, Loss: 0.0765
# Train Layer: 0, Epoch: 6/20, Iter: 600/600, Loss: 0.0758
# Train Layer: 0, Epoch: 7/20, Iter: 10/600, Loss: 0.0724
# Train Layer: 0, Epoch: 7/20, Iter: 20/600, Loss: 0.0754
# Train Layer: 0, Epoch: 7/20, Iter: 30/600, Loss: 0.0776
# Train Layer: 0, Epoch: 7/20, Iter: 40/600, Loss: 0.0756
# Train Layer: 0, Epoch: 7/20, Iter: 50/600, Loss: 0.0764
# Train Layer: 0, Epoch: 7/20, Iter: 60/600, Loss: 0.0755
# Train Layer: 0, Epoch: 7/20, Iter: 70/600, Loss: 0.0737
# Train Layer: 0, Epoch: 7/20, Iter: 80/600, Loss: 0.0740
# Train Layer: 0, Epoch: 7/20, Iter: 90/600, Loss: 0.0766
# Train Layer: 0, Epoch: 7/20, Iter: 100/600, Loss: 0.0754
# Train Layer: 0, Epoch: 7/20, Iter: 110/600, Loss: 0.0749
# Train Layer: 0, Epoch: 7/20, Iter: 120/600, Loss: 0.0696
# Train Layer: 0, Epoch: 7/20, Iter: 130/600, Loss: 0.0734
# Train Layer: 0, Epoch: 7/20, Iter: 140/600, Loss: 0.0737
# Train Layer: 0, Epoch: 7/20, Iter: 150/600, Loss: 0.0750
# Train Layer: 0, Epoch: 7/20, Iter: 160/600, Loss: 0.0736
# Train Layer: 0, Epoch: 7/20, Iter: 170/600, Loss: 0.0747
# Train Layer: 0, Epoch: 7/20, Iter: 180/600, Loss: 0.0750
# Train Layer: 0, Epoch: 7/20, Iter: 190/600, Loss: 0.0736
# Train Layer: 0, Epoch: 7/20, Iter: 200/600, Loss: 0.0757
# Train Layer: 0, Epoch: 7/20, Iter: 210/600, Loss: 0.0770
# Train Layer: 0, Epoch: 7/20, Iter: 220/600, Loss: 0.0745
# Train Layer: 0, Epoch: 7/20, Iter: 230/600, Loss: 0.0781
# Train Layer: 0, Epoch: 7/20, Iter: 240/600, Loss: 0.0763
# Train Layer: 0, Epoch: 7/20, Iter: 250/600, Loss: 0.0733
# Train Layer: 0, Epoch: 7/20, Iter: 260/600, Loss: 0.0777
# Train Layer: 0, Epoch: 7/20, Iter: 270/600, Loss: 0.0766
# Train Layer: 0, Epoch: 7/20, Iter: 280/600, Loss: 0.0759
# Train Layer: 0, Epoch: 7/20, Iter: 290/600, Loss: 0.0742
# Train Layer: 0, Epoch: 7/20, Iter: 300/600, Loss: 0.0724
# Train Layer: 0, Epoch: 7/20, Iter: 310/600, Loss: 0.0731
# Train Layer: 0, Epoch: 7/20, Iter: 320/600, Loss: 0.0736
# Train Layer: 0, Epoch: 7/20, Iter: 330/600, Loss: 0.0762
# Train Layer: 0, Epoch: 7/20, Iter: 340/600, Loss: 0.0757
# Train Layer: 0, Epoch: 7/20, Iter: 350/600, Loss: 0.0755
# Train Layer: 0, Epoch: 7/20, Iter: 360/600, Loss: 0.0781
# Train Layer: 0, Epoch: 7/20, Iter: 370/600, Loss: 0.0721
# Train Layer: 0, Epoch: 7/20, Iter: 380/600, Loss: 0.0775
# Train Layer: 0, Epoch: 7/20, Iter: 390/600, Loss: 0.0744
# Train Layer: 0, Epoch: 7/20, Iter: 400/600, Loss: 0.0749
# Train Layer: 0, Epoch: 7/20, Iter: 410/600, Loss: 0.0756
# Train Layer: 0, Epoch: 7/20, Iter: 420/600, Loss: 0.0722
# Train Layer: 0, Epoch: 7/20, Iter: 430/600, Loss: 0.0726
# Train Layer: 0, Epoch: 7/20, Iter: 440/600, Loss: 0.0749
# Train Layer: 0, Epoch: 7/20, Iter: 450/600, Loss: 0.0732
# Train Layer: 0, Epoch: 7/20, Iter: 460/600, Loss: 0.0709
# Train Layer: 0, Epoch: 7/20, Iter: 470/600, Loss: 0.0721
# Train Layer: 0, Epoch: 7/20, Iter: 480/600, Loss: 0.0713
# Train Layer: 0, Epoch: 7/20, Iter: 490/600, Loss: 0.0694
# Train Layer: 0, Epoch: 7/20, Iter: 500/600, Loss: 0.0747
# Train Layer: 0, Epoch: 7/20, Iter: 510/600, Loss: 0.0694
# Train Layer: 0, Epoch: 7/20, Iter: 520/600, Loss: 0.0743
# Train Layer: 0, Epoch: 7/20, Iter: 530/600, Loss: 0.0714
# Train Layer: 0, Epoch: 7/20, Iter: 540/600, Loss: 0.0724
# Train Layer: 0, Epoch: 7/20, Iter: 550/600, Loss: 0.0744
# Train Layer: 0, Epoch: 7/20, Iter: 560/600, Loss: 0.0759
# Train Layer: 0, Epoch: 7/20, Iter: 570/600, Loss: 0.0748
# Train Layer: 0, Epoch: 7/20, Iter: 580/600, Loss: 0.0748
# Train Layer: 0, Epoch: 7/20, Iter: 590/600, Loss: 0.0723
# Train Layer: 0, Epoch: 7/20, Iter: 600/600, Loss: 0.0760
# Train Layer: 0, Epoch: 8/20, Iter: 10/600, Loss: 0.0728
# Train Layer: 0, Epoch: 8/20, Iter: 20/600, Loss: 0.0709
# Train Layer: 0, Epoch: 8/20, Iter: 30/600, Loss: 0.0726
# Train Layer: 0, Epoch: 8/20, Iter: 40/600, Loss: 0.0753
# Train Layer: 0, Epoch: 8/20, Iter: 50/600, Loss: 0.0724
# Train Layer: 0, Epoch: 8/20, Iter: 60/600, Loss: 0.0719
# Train Layer: 0, Epoch: 8/20, Iter: 70/600, Loss: 0.0765
# Train Layer: 0, Epoch: 8/20, Iter: 80/600, Loss: 0.0733
# Train Layer: 0, Epoch: 8/20, Iter: 90/600, Loss: 0.0750
# Train Layer: 0, Epoch: 8/20, Iter: 100/600, Loss: 0.0692
# Train Layer: 0, Epoch: 8/20, Iter: 110/600, Loss: 0.0718
# Train Layer: 0, Epoch: 8/20, Iter: 120/600, Loss: 0.0741
# Train Layer: 0, Epoch: 8/20, Iter: 130/600, Loss: 0.0741
# Train Layer: 0, Epoch: 8/20, Iter: 140/600, Loss: 0.0713
# Train Layer: 0, Epoch: 8/20, Iter: 150/600, Loss: 0.0736
# Train Layer: 0, Epoch: 8/20, Iter: 160/600, Loss: 0.0752
# Train Layer: 0, Epoch: 8/20, Iter: 170/600, Loss: 0.0726
# Train Layer: 0, Epoch: 8/20, Iter: 180/600, Loss: 0.0695
# Train Layer: 0, Epoch: 8/20, Iter: 190/600, Loss: 0.0730
# Train Layer: 0, Epoch: 8/20, Iter: 200/600, Loss: 0.0719
# Train Layer: 0, Epoch: 8/20, Iter: 210/600, Loss: 0.0734
# Train Layer: 0, Epoch: 8/20, Iter: 220/600, Loss: 0.0708
# Train Layer: 0, Epoch: 8/20, Iter: 230/600, Loss: 0.0688
# Train Layer: 0, Epoch: 8/20, Iter: 240/600, Loss: 0.0701
# Train Layer: 0, Epoch: 8/20, Iter: 250/600, Loss: 0.0736
# Train Layer: 0, Epoch: 8/20, Iter: 260/600, Loss: 0.0746
# Train Layer: 0, Epoch: 8/20, Iter: 270/600, Loss: 0.0719
# Train Layer: 0, Epoch: 8/20, Iter: 280/600, Loss: 0.0752
# Train Layer: 0, Epoch: 8/20, Iter: 290/600, Loss: 0.0751
# Train Layer: 0, Epoch: 8/20, Iter: 300/600, Loss: 0.0731
# Train Layer: 0, Epoch: 8/20, Iter: 310/600, Loss: 0.0771
# Train Layer: 0, Epoch: 8/20, Iter: 320/600, Loss: 0.0723
# Train Layer: 0, Epoch: 8/20, Iter: 330/600, Loss: 0.0715
# Train Layer: 0, Epoch: 8/20, Iter: 340/600, Loss: 0.0744
# Train Layer: 0, Epoch: 8/20, Iter: 350/600, Loss: 0.0713
# Train Layer: 0, Epoch: 8/20, Iter: 360/600, Loss: 0.0705
# Train Layer: 0, Epoch: 8/20, Iter: 370/600, Loss: 0.0736
# Train Layer: 0, Epoch: 8/20, Iter: 380/600, Loss: 0.0711
# Train Layer: 0, Epoch: 8/20, Iter: 390/600, Loss: 0.0723
# Train Layer: 0, Epoch: 8/20, Iter: 400/600, Loss: 0.0720
# Train Layer: 0, Epoch: 8/20, Iter: 410/600, Loss: 0.0738
# Train Layer: 0, Epoch: 8/20, Iter: 420/600, Loss: 0.0758
# Train Layer: 0, Epoch: 8/20, Iter: 430/600, Loss: 0.0748
# Train Layer: 0, Epoch: 8/20, Iter: 440/600, Loss: 0.0711
# Train Layer: 0, Epoch: 8/20, Iter: 450/600, Loss: 0.0728
# Train Layer: 0, Epoch: 8/20, Iter: 460/600, Loss: 0.0702
# Train Layer: 0, Epoch: 8/20, Iter: 470/600, Loss: 0.0706
# Train Layer: 0, Epoch: 8/20, Iter: 480/600, Loss: 0.0687
# Train Layer: 0, Epoch: 8/20, Iter: 490/600, Loss: 0.0730
# Train Layer: 0, Epoch: 8/20, Iter: 500/600, Loss: 0.0721
# Train Layer: 0, Epoch: 8/20, Iter: 510/600, Loss: 0.0733
# Train Layer: 0, Epoch: 8/20, Iter: 520/600, Loss: 0.0727
# Train Layer: 0, Epoch: 8/20, Iter: 530/600, Loss: 0.0748
# Train Layer: 0, Epoch: 8/20, Iter: 540/600, Loss: 0.0728
# Train Layer: 0, Epoch: 8/20, Iter: 550/600, Loss: 0.0708
# Train Layer: 0, Epoch: 8/20, Iter: 560/600, Loss: 0.0710
# Train Layer: 0, Epoch: 8/20, Iter: 570/600, Loss: 0.0720
# Train Layer: 0, Epoch: 8/20, Iter: 580/600, Loss: 0.0675
# Train Layer: 0, Epoch: 8/20, Iter: 590/600, Loss: 0.0729
# Train Layer: 0, Epoch: 8/20, Iter: 600/600, Loss: 0.0688
# Train Layer: 0, Epoch: 9/20, Iter: 10/600, Loss: 0.0683
# Train Layer: 0, Epoch: 9/20, Iter: 20/600, Loss: 0.0732
# Train Layer: 0, Epoch: 9/20, Iter: 30/600, Loss: 0.0734
# Train Layer: 0, Epoch: 9/20, Iter: 40/600, Loss: 0.0722
# Train Layer: 0, Epoch: 9/20, Iter: 50/600, Loss: 0.0716
# Train Layer: 0, Epoch: 9/20, Iter: 60/600, Loss: 0.0691
# Train Layer: 0, Epoch: 9/20, Iter: 70/600, Loss: 0.0754
# Train Layer: 0, Epoch: 9/20, Iter: 80/600, Loss: 0.0709
# Train Layer: 0, Epoch: 9/20, Iter: 90/600, Loss: 0.0716
# Train Layer: 0, Epoch: 9/20, Iter: 100/600, Loss: 0.0742
# Train Layer: 0, Epoch: 9/20, Iter: 110/600, Loss: 0.0738
# Train Layer: 0, Epoch: 9/20, Iter: 120/600, Loss: 0.0730
# Train Layer: 0, Epoch: 9/20, Iter: 130/600, Loss: 0.0710
# Train Layer: 0, Epoch: 9/20, Iter: 140/600, Loss: 0.0706
# Train Layer: 0, Epoch: 9/20, Iter: 150/600, Loss: 0.0707
# Train Layer: 0, Epoch: 9/20, Iter: 160/600, Loss: 0.0719
# Train Layer: 0, Epoch: 9/20, Iter: 170/600, Loss: 0.0726
# Train Layer: 0, Epoch: 9/20, Iter: 180/600, Loss: 0.0713
# Train Layer: 0, Epoch: 9/20, Iter: 190/600, Loss: 0.0718
# Train Layer: 0, Epoch: 9/20, Iter: 200/600, Loss: 0.0703
# Train Layer: 0, Epoch: 9/20, Iter: 210/600, Loss: 0.0738
# Train Layer: 0, Epoch: 9/20, Iter: 220/600, Loss: 0.0707
# Train Layer: 0, Epoch: 9/20, Iter: 230/600, Loss: 0.0691
# Train Layer: 0, Epoch: 9/20, Iter: 240/600, Loss: 0.0719
# Train Layer: 0, Epoch: 9/20, Iter: 250/600, Loss: 0.0733
# Train Layer: 0, Epoch: 9/20, Iter: 260/600, Loss: 0.0708
# Train Layer: 0, Epoch: 9/20, Iter: 270/600, Loss: 0.0721
# Train Layer: 0, Epoch: 9/20, Iter: 280/600, Loss: 0.0684
# Train Layer: 0, Epoch: 9/20, Iter: 290/600, Loss: 0.0713
# Train Layer: 0, Epoch: 9/20, Iter: 300/600, Loss: 0.0716
# Train Layer: 0, Epoch: 9/20, Iter: 310/600, Loss: 0.0720
# Train Layer: 0, Epoch: 9/20, Iter: 320/600, Loss: 0.0707
# Train Layer: 0, Epoch: 9/20, Iter: 330/600, Loss: 0.0733
# Train Layer: 0, Epoch: 9/20, Iter: 340/600, Loss: 0.0712
# Train Layer: 0, Epoch: 9/20, Iter: 350/600, Loss: 0.0704
# Train Layer: 0, Epoch: 9/20, Iter: 360/600, Loss: 0.0713
# Train Layer: 0, Epoch: 9/20, Iter: 370/600, Loss: 0.0734
# Train Layer: 0, Epoch: 9/20, Iter: 380/600, Loss: 0.0673
# Train Layer: 0, Epoch: 9/20, Iter: 390/600, Loss: 0.0718
# Train Layer: 0, Epoch: 9/20, Iter: 400/600, Loss: 0.0706
# Train Layer: 0, Epoch: 9/20, Iter: 410/600, Loss: 0.0697
# Train Layer: 0, Epoch: 9/20, Iter: 420/600, Loss: 0.0682
# Train Layer: 0, Epoch: 9/20, Iter: 430/600, Loss: 0.0706
# Train Layer: 0, Epoch: 9/20, Iter: 440/600, Loss: 0.0680
# Train Layer: 0, Epoch: 9/20, Iter: 450/600, Loss: 0.0750
# Train Layer: 0, Epoch: 9/20, Iter: 460/600, Loss: 0.0741
# Train Layer: 0, Epoch: 9/20, Iter: 470/600, Loss: 0.0686
# Train Layer: 0, Epoch: 9/20, Iter: 480/600, Loss: 0.0680
# Train Layer: 0, Epoch: 9/20, Iter: 490/600, Loss: 0.0738
# Train Layer: 0, Epoch: 9/20, Iter: 500/600, Loss: 0.0709
# Train Layer: 0, Epoch: 9/20, Iter: 510/600, Loss: 0.0726
# Train Layer: 0, Epoch: 9/20, Iter: 520/600, Loss: 0.0698
# Train Layer: 0, Epoch: 9/20, Iter: 530/600, Loss: 0.0705
# Train Layer: 0, Epoch: 9/20, Iter: 540/600, Loss: 0.0699
# Train Layer: 0, Epoch: 9/20, Iter: 550/600, Loss: 0.0719
# Train Layer: 0, Epoch: 9/20, Iter: 560/600, Loss: 0.0693
# Train Layer: 0, Epoch: 9/20, Iter: 570/600, Loss: 0.0734
# Train Layer: 0, Epoch: 9/20, Iter: 580/600, Loss: 0.0693
# Train Layer: 0, Epoch: 9/20, Iter: 590/600, Loss: 0.0742
# Train Layer: 0, Epoch: 9/20, Iter: 600/600, Loss: 0.0703
# Train Layer: 0, Epoch: 10/20, Iter: 10/600, Loss: 0.0714
# Train Layer: 0, Epoch: 10/20, Iter: 20/600, Loss: 0.0715
# Train Layer: 0, Epoch: 10/20, Iter: 30/600, Loss: 0.0696
# Train Layer: 0, Epoch: 10/20, Iter: 40/600, Loss: 0.0695
# Train Layer: 0, Epoch: 10/20, Iter: 50/600, Loss: 0.0675
# Train Layer: 0, Epoch: 10/20, Iter: 60/600, Loss: 0.0734
# Train Layer: 0, Epoch: 10/20, Iter: 70/600, Loss: 0.0715
# Train Layer: 0, Epoch: 10/20, Iter: 80/600, Loss: 0.0708
# Train Layer: 0, Epoch: 10/20, Iter: 90/600, Loss: 0.0736
# Train Layer: 0, Epoch: 10/20, Iter: 100/600, Loss: 0.0687
# Train Layer: 0, Epoch: 10/20, Iter: 110/600, Loss: 0.0698
# Train Layer: 0, Epoch: 10/20, Iter: 120/600, Loss: 0.0675
# Train Layer: 0, Epoch: 10/20, Iter: 130/600, Loss: 0.0707
# Train Layer: 0, Epoch: 10/20, Iter: 140/600, Loss: 0.0705
# Train Layer: 0, Epoch: 10/20, Iter: 150/600, Loss: 0.0695
# Train Layer: 0, Epoch: 10/20, Iter: 160/600, Loss: 0.0714
# Train Layer: 0, Epoch: 10/20, Iter: 170/600, Loss: 0.0708
# Train Layer: 0, Epoch: 10/20, Iter: 180/600, Loss: 0.0710
# Train Layer: 0, Epoch: 10/20, Iter: 190/600, Loss: 0.0688
# Train Layer: 0, Epoch: 10/20, Iter: 200/600, Loss: 0.0729
# Train Layer: 0, Epoch: 10/20, Iter: 210/600, Loss: 0.0707
# Train Layer: 0, Epoch: 10/20, Iter: 220/600, Loss: 0.0699
# Train Layer: 0, Epoch: 10/20, Iter: 230/600, Loss: 0.0696
# Train Layer: 0, Epoch: 10/20, Iter: 240/600, Loss: 0.0693
# Train Layer: 0, Epoch: 10/20, Iter: 250/600, Loss: 0.0700
# Train Layer: 0, Epoch: 10/20, Iter: 260/600, Loss: 0.0694
# Train Layer: 0, Epoch: 10/20, Iter: 270/600, Loss: 0.0700
# Train Layer: 0, Epoch: 10/20, Iter: 280/600, Loss: 0.0728
# Train Layer: 0, Epoch: 10/20, Iter: 290/600, Loss: 0.0690
# Train Layer: 0, Epoch: 10/20, Iter: 300/600, Loss: 0.0700
# Train Layer: 0, Epoch: 10/20, Iter: 310/600, Loss: 0.0710
# Train Layer: 0, Epoch: 10/20, Iter: 320/600, Loss: 0.0695
# Train Layer: 0, Epoch: 10/20, Iter: 330/600, Loss: 0.0711
# Train Layer: 0, Epoch: 10/20, Iter: 340/600, Loss: 0.0697
# Train Layer: 0, Epoch: 10/20, Iter: 350/600, Loss: 0.0699
# Train Layer: 0, Epoch: 10/20, Iter: 360/600, Loss: 0.0692
# Train Layer: 0, Epoch: 10/20, Iter: 370/600, Loss: 0.0744
# Train Layer: 0, Epoch: 10/20, Iter: 380/600, Loss: 0.0688
# Train Layer: 0, Epoch: 10/20, Iter: 390/600, Loss: 0.0722
# Train Layer: 0, Epoch: 10/20, Iter: 400/600, Loss: 0.0683
# Train Layer: 0, Epoch: 10/20, Iter: 410/600, Loss: 0.0691
# Train Layer: 0, Epoch: 10/20, Iter: 420/600, Loss: 0.0714
# Train Layer: 0, Epoch: 10/20, Iter: 430/600, Loss: 0.0708
# Train Layer: 0, Epoch: 10/20, Iter: 440/600, Loss: 0.0719
# Train Layer: 0, Epoch: 10/20, Iter: 450/600, Loss: 0.0702
# Train Layer: 0, Epoch: 10/20, Iter: 460/600, Loss: 0.0682
# Train Layer: 0, Epoch: 10/20, Iter: 470/600, Loss: 0.0713
# Train Layer: 0, Epoch: 10/20, Iter: 480/600, Loss: 0.0710
# Train Layer: 0, Epoch: 10/20, Iter: 490/600, Loss: 0.0691
# Train Layer: 0, Epoch: 10/20, Iter: 500/600, Loss: 0.0723
# Train Layer: 0, Epoch: 10/20, Iter: 510/600, Loss: 0.0687
# Train Layer: 0, Epoch: 10/20, Iter: 520/600, Loss: 0.0720
# Train Layer: 0, Epoch: 10/20, Iter: 530/600, Loss: 0.0714
# Train Layer: 0, Epoch: 10/20, Iter: 540/600, Loss: 0.0702
# Train Layer: 0, Epoch: 10/20, Iter: 550/600, Loss: 0.0695
# Train Layer: 0, Epoch: 10/20, Iter: 560/600, Loss: 0.0679
# Train Layer: 0, Epoch: 10/20, Iter: 570/600, Loss: 0.0731
# Train Layer: 0, Epoch: 10/20, Iter: 580/600, Loss: 0.0697
# Train Layer: 0, Epoch: 10/20, Iter: 590/600, Loss: 0.0720
# Train Layer: 0, Epoch: 10/20, Iter: 600/600, Loss: 0.0718
# Train Layer: 0, Epoch: 11/20, Iter: 10/600, Loss: 0.0679
# Train Layer: 0, Epoch: 11/20, Iter: 20/600, Loss: 0.0689
# Train Layer: 0, Epoch: 11/20, Iter: 30/600, Loss: 0.0703
# Train Layer: 0, Epoch: 11/20, Iter: 40/600, Loss: 0.0717
# Train Layer: 0, Epoch: 11/20, Iter: 50/600, Loss: 0.0724
# Train Layer: 0, Epoch: 11/20, Iter: 60/600, Loss: 0.0686
# Train Layer: 0, Epoch: 11/20, Iter: 70/600, Loss: 0.0680
# Train Layer: 0, Epoch: 11/20, Iter: 80/600, Loss: 0.0691
# Train Layer: 0, Epoch: 11/20, Iter: 90/600, Loss: 0.0707
# Train Layer: 0, Epoch: 11/20, Iter: 100/600, Loss: 0.0686
# Train Layer: 0, Epoch: 11/20, Iter: 110/600, Loss: 0.0692
# Train Layer: 0, Epoch: 11/20, Iter: 120/600, Loss: 0.0682
# Train Layer: 0, Epoch: 11/20, Iter: 130/600, Loss: 0.0673
# Train Layer: 0, Epoch: 11/20, Iter: 140/600, Loss: 0.0680
# Train Layer: 0, Epoch: 11/20, Iter: 150/600, Loss: 0.0699
# Train Layer: 0, Epoch: 11/20, Iter: 160/600, Loss: 0.0680
# Train Layer: 0, Epoch: 11/20, Iter: 170/600, Loss: 0.0713
# Train Layer: 0, Epoch: 11/20, Iter: 180/600, Loss: 0.0704
# Train Layer: 0, Epoch: 11/20, Iter: 190/600, Loss: 0.0705
# Train Layer: 0, Epoch: 11/20, Iter: 200/600, Loss: 0.0711
# Train Layer: 0, Epoch: 11/20, Iter: 210/600, Loss: 0.0686
# Train Layer: 0, Epoch: 11/20, Iter: 220/600, Loss: 0.0705
# Train Layer: 0, Epoch: 11/20, Iter: 230/600, Loss: 0.0670
# Train Layer: 0, Epoch: 11/20, Iter: 240/600, Loss: 0.0692
# Train Layer: 0, Epoch: 11/20, Iter: 250/600, Loss: 0.0700
# Train Layer: 0, Epoch: 11/20, Iter: 260/600, Loss: 0.0672
# Train Layer: 0, Epoch: 11/20, Iter: 270/600, Loss: 0.0694
# Train Layer: 0, Epoch: 11/20, Iter: 280/600, Loss: 0.0701
# Train Layer: 0, Epoch: 11/20, Iter: 290/600, Loss: 0.0668
# Train Layer: 0, Epoch: 11/20, Iter: 300/600, Loss: 0.0695
# Train Layer: 0, Epoch: 11/20, Iter: 310/600, Loss: 0.0696
# Train Layer: 0, Epoch: 11/20, Iter: 320/600, Loss: 0.0690
# Train Layer: 0, Epoch: 11/20, Iter: 330/600, Loss: 0.0696
# Train Layer: 0, Epoch: 11/20, Iter: 340/600, Loss: 0.0689
# Train Layer: 0, Epoch: 11/20, Iter: 350/600, Loss: 0.0658
# Train Layer: 0, Epoch: 11/20, Iter: 360/600, Loss: 0.0687
# Train Layer: 0, Epoch: 11/20, Iter: 370/600, Loss: 0.0696
# Train Layer: 0, Epoch: 11/20, Iter: 380/600, Loss: 0.0688
# Train Layer: 0, Epoch: 11/20, Iter: 390/600, Loss: 0.0710
# Train Layer: 0, Epoch: 11/20, Iter: 400/600, Loss: 0.0676
# Train Layer: 0, Epoch: 11/20, Iter: 410/600, Loss: 0.0702
# Train Layer: 0, Epoch: 11/20, Iter: 420/600, Loss: 0.0701
# Train Layer: 0, Epoch: 11/20, Iter: 430/600, Loss: 0.0697
# Train Layer: 0, Epoch: 11/20, Iter: 440/600, Loss: 0.0698
# Train Layer: 0, Epoch: 11/20, Iter: 450/600, Loss: 0.0689
# Train Layer: 0, Epoch: 11/20, Iter: 460/600, Loss: 0.0683
# Train Layer: 0, Epoch: 11/20, Iter: 470/600, Loss: 0.0702
# Train Layer: 0, Epoch: 11/20, Iter: 480/600, Loss: 0.0699
# Train Layer: 0, Epoch: 11/20, Iter: 490/600, Loss: 0.0682
# Train Layer: 0, Epoch: 11/20, Iter: 500/600, Loss: 0.0691
# Train Layer: 0, Epoch: 11/20, Iter: 510/600, Loss: 0.0690
# Train Layer: 0, Epoch: 11/20, Iter: 520/600, Loss: 0.0667
# Train Layer: 0, Epoch: 11/20, Iter: 530/600, Loss: 0.0690
# Train Layer: 0, Epoch: 11/20, Iter: 540/600, Loss: 0.0685
# Train Layer: 0, Epoch: 11/20, Iter: 550/600, Loss: 0.0704
# Train Layer: 0, Epoch: 11/20, Iter: 560/600, Loss: 0.0681
# Train Layer: 0, Epoch: 11/20, Iter: 570/600, Loss: 0.0693
# Train Layer: 0, Epoch: 11/20, Iter: 580/600, Loss: 0.0692
# Train Layer: 0, Epoch: 11/20, Iter: 590/600, Loss: 0.0692
# Train Layer: 0, Epoch: 11/20, Iter: 600/600, Loss: 0.0671
# Train Layer: 0, Epoch: 12/20, Iter: 10/600, Loss: 0.0671
# Train Layer: 0, Epoch: 12/20, Iter: 20/600, Loss: 0.0690
# Train Layer: 0, Epoch: 12/20, Iter: 30/600, Loss: 0.0670
# Train Layer: 0, Epoch: 12/20, Iter: 40/600, Loss: 0.0687
# Train Layer: 0, Epoch: 12/20, Iter: 50/600, Loss: 0.0676
# Train Layer: 0, Epoch: 12/20, Iter: 60/600, Loss: 0.0685
# Train Layer: 0, Epoch: 12/20, Iter: 70/600, Loss: 0.0696
# Train Layer: 0, Epoch: 12/20, Iter: 80/600, Loss: 0.0658
# Train Layer: 0, Epoch: 12/20, Iter: 90/600, Loss: 0.0683
# Train Layer: 0, Epoch: 12/20, Iter: 100/600, Loss: 0.0689
# Train Layer: 0, Epoch: 12/20, Iter: 110/600, Loss: 0.0662
# Train Layer: 0, Epoch: 12/20, Iter: 120/600, Loss: 0.0680
# Train Layer: 0, Epoch: 12/20, Iter: 130/600, Loss: 0.0693
# Train Layer: 0, Epoch: 12/20, Iter: 140/600, Loss: 0.0648
# Train Layer: 0, Epoch: 12/20, Iter: 150/600, Loss: 0.0687
# Train Layer: 0, Epoch: 12/20, Iter: 160/600, Loss: 0.0686
# Train Layer: 0, Epoch: 12/20, Iter: 170/600, Loss: 0.0696
# Train Layer: 0, Epoch: 12/20, Iter: 180/600, Loss: 0.0691
# Train Layer: 0, Epoch: 12/20, Iter: 190/600, Loss: 0.0672
# Train Layer: 0, Epoch: 12/20, Iter: 200/600, Loss: 0.0674
# Train Layer: 0, Epoch: 12/20, Iter: 210/600, Loss: 0.0691
# Train Layer: 0, Epoch: 12/20, Iter: 220/600, Loss: 0.0680
# Train Layer: 0, Epoch: 12/20, Iter: 230/600, Loss: 0.0684
# Train Layer: 0, Epoch: 12/20, Iter: 240/600, Loss: 0.0675
# Train Layer: 0, Epoch: 12/20, Iter: 250/600, Loss: 0.0682
# Train Layer: 0, Epoch: 12/20, Iter: 260/600, Loss: 0.0715
# Train Layer: 0, Epoch: 12/20, Iter: 270/600, Loss: 0.0688
# Train Layer: 0, Epoch: 12/20, Iter: 280/600, Loss: 0.0707
# Train Layer: 0, Epoch: 12/20, Iter: 290/600, Loss: 0.0690
# Train Layer: 0, Epoch: 12/20, Iter: 300/600, Loss: 0.0681
# Train Layer: 0, Epoch: 12/20, Iter: 310/600, Loss: 0.0682
# Train Layer: 0, Epoch: 12/20, Iter: 320/600, Loss: 0.0705
# Train Layer: 0, Epoch: 12/20, Iter: 330/600, Loss: 0.0675
# Train Layer: 0, Epoch: 12/20, Iter: 340/600, Loss: 0.0694
# Train Layer: 0, Epoch: 12/20, Iter: 350/600, Loss: 0.0697
# Train Layer: 0, Epoch: 12/20, Iter: 360/600, Loss: 0.0698
# Train Layer: 0, Epoch: 12/20, Iter: 370/600, Loss: 0.0669
# Train Layer: 0, Epoch: 12/20, Iter: 380/600, Loss: 0.0686
# Train Layer: 0, Epoch: 12/20, Iter: 390/600, Loss: 0.0688
# Train Layer: 0, Epoch: 12/20, Iter: 400/600, Loss: 0.0686
# Train Layer: 0, Epoch: 12/20, Iter: 410/600, Loss: 0.0671
# Train Layer: 0, Epoch: 12/20, Iter: 420/600, Loss: 0.0666
# Train Layer: 0, Epoch: 12/20, Iter: 430/600, Loss: 0.0672
# Train Layer: 0, Epoch: 12/20, Iter: 440/600, Loss: 0.0689
# Train Layer: 0, Epoch: 12/20, Iter: 450/600, Loss: 0.0658
# Train Layer: 0, Epoch: 12/20, Iter: 460/600, Loss: 0.0688
# Train Layer: 0, Epoch: 12/20, Iter: 470/600, Loss: 0.0681
# Train Layer: 0, Epoch: 12/20, Iter: 480/600, Loss: 0.0671
# Train Layer: 0, Epoch: 12/20, Iter: 490/600, Loss: 0.0688
# Train Layer: 0, Epoch: 12/20, Iter: 500/600, Loss: 0.0661
# Train Layer: 0, Epoch: 12/20, Iter: 510/600, Loss: 0.0721
# Train Layer: 0, Epoch: 12/20, Iter: 520/600, Loss: 0.0673
# Train Layer: 0, Epoch: 12/20, Iter: 530/600, Loss: 0.0710
# Train Layer: 0, Epoch: 12/20, Iter: 540/600, Loss: 0.0695
# Train Layer: 0, Epoch: 12/20, Iter: 550/600, Loss: 0.0689
# Train Layer: 0, Epoch: 12/20, Iter: 560/600, Loss: 0.0675
# Train Layer: 0, Epoch: 12/20, Iter: 570/600, Loss: 0.0657
# Train Layer: 0, Epoch: 12/20, Iter: 580/600, Loss: 0.0695
# Train Layer: 0, Epoch: 12/20, Iter: 590/600, Loss: 0.0671
# Train Layer: 0, Epoch: 12/20, Iter: 600/600, Loss: 0.0734
# Train Layer: 0, Epoch: 13/20, Iter: 10/600, Loss: 0.0672
# Train Layer: 0, Epoch: 13/20, Iter: 20/600, Loss: 0.0705
# Train Layer: 0, Epoch: 13/20, Iter: 30/600, Loss: 0.0684
# Train Layer: 0, Epoch: 13/20, Iter: 40/600, Loss: 0.0698
# Train Layer: 0, Epoch: 13/20, Iter: 50/600, Loss: 0.0682
# Train Layer: 0, Epoch: 13/20, Iter: 60/600, Loss: 0.0657
# Train Layer: 0, Epoch: 13/20, Iter: 70/600, Loss: 0.0685
# Train Layer: 0, Epoch: 13/20, Iter: 80/600, Loss: 0.0688
# Train Layer: 0, Epoch: 13/20, Iter: 90/600, Loss: 0.0685
# Train Layer: 0, Epoch: 13/20, Iter: 100/600, Loss: 0.0681
# Train Layer: 0, Epoch: 13/20, Iter: 110/600, Loss: 0.0678
# Train Layer: 0, Epoch: 13/20, Iter: 120/600, Loss: 0.0705
# Train Layer: 0, Epoch: 13/20, Iter: 130/600, Loss: 0.0673
# Train Layer: 0, Epoch: 13/20, Iter: 140/600, Loss: 0.0692
# Train Layer: 0, Epoch: 13/20, Iter: 150/600, Loss: 0.0648
# Train Layer: 0, Epoch: 13/20, Iter: 160/600, Loss: 0.0703
# Train Layer: 0, Epoch: 13/20, Iter: 170/600, Loss: 0.0695
# Train Layer: 0, Epoch: 13/20, Iter: 180/600, Loss: 0.0689
# Train Layer: 0, Epoch: 13/20, Iter: 190/600, Loss: 0.0703
# Train Layer: 0, Epoch: 13/20, Iter: 200/600, Loss: 0.0682
# Train Layer: 0, Epoch: 13/20, Iter: 210/600, Loss: 0.0667
# Train Layer: 0, Epoch: 13/20, Iter: 220/600, Loss: 0.0687
# Train Layer: 0, Epoch: 13/20, Iter: 230/600, Loss: 0.0694
# Train Layer: 0, Epoch: 13/20, Iter: 240/600, Loss: 0.0694
# Train Layer: 0, Epoch: 13/20, Iter: 250/600, Loss: 0.0689
# Train Layer: 0, Epoch: 13/20, Iter: 260/600, Loss: 0.0692
# Train Layer: 0, Epoch: 13/20, Iter: 270/600, Loss: 0.0687
# Train Layer: 0, Epoch: 13/20, Iter: 280/600, Loss: 0.0710
# Train Layer: 0, Epoch: 13/20, Iter: 290/600, Loss: 0.0665
# Train Layer: 0, Epoch: 13/20, Iter: 300/600, Loss: 0.0682
# Train Layer: 0, Epoch: 13/20, Iter: 310/600, Loss: 0.0704
# Train Layer: 0, Epoch: 13/20, Iter: 320/600, Loss: 0.0693
# Train Layer: 0, Epoch: 13/20, Iter: 330/600, Loss: 0.0628
# Train Layer: 0, Epoch: 13/20, Iter: 340/600, Loss: 0.0656
# Train Layer: 0, Epoch: 13/20, Iter: 350/600, Loss: 0.0712
# Train Layer: 0, Epoch: 13/20, Iter: 360/600, Loss: 0.0661
# Train Layer: 0, Epoch: 13/20, Iter: 370/600, Loss: 0.0687
# Train Layer: 0, Epoch: 13/20, Iter: 380/600, Loss: 0.0699
# Train Layer: 0, Epoch: 13/20, Iter: 390/600, Loss: 0.0683
# Train Layer: 0, Epoch: 13/20, Iter: 400/600, Loss: 0.0695
# Train Layer: 0, Epoch: 13/20, Iter: 410/600, Loss: 0.0687
# Train Layer: 0, Epoch: 13/20, Iter: 420/600, Loss: 0.0690
# Train Layer: 0, Epoch: 13/20, Iter: 430/600, Loss: 0.0668
# Train Layer: 0, Epoch: 13/20, Iter: 440/600, Loss: 0.0696
# Train Layer: 0, Epoch: 13/20, Iter: 450/600, Loss: 0.0663
# Train Layer: 0, Epoch: 13/20, Iter: 460/600, Loss: 0.0691
# Train Layer: 0, Epoch: 13/20, Iter: 470/600, Loss: 0.0672
# Train Layer: 0, Epoch: 13/20, Iter: 480/600, Loss: 0.0670
# Train Layer: 0, Epoch: 13/20, Iter: 490/600, Loss: 0.0655
# Train Layer: 0, Epoch: 13/20, Iter: 500/600, Loss: 0.0679
# Train Layer: 0, Epoch: 13/20, Iter: 510/600, Loss: 0.0721
# Train Layer: 0, Epoch: 13/20, Iter: 520/600, Loss: 0.0697
# Train Layer: 0, Epoch: 13/20, Iter: 530/600, Loss: 0.0667
# Train Layer: 0, Epoch: 13/20, Iter: 540/600, Loss: 0.0685
# Train Layer: 0, Epoch: 13/20, Iter: 550/600, Loss: 0.0671
# Train Layer: 0, Epoch: 13/20, Iter: 560/600, Loss: 0.0680
# Train Layer: 0, Epoch: 13/20, Iter: 570/600, Loss: 0.0685
# Train Layer: 0, Epoch: 13/20, Iter: 580/600, Loss: 0.0676
# Train Layer: 0, Epoch: 13/20, Iter: 590/600, Loss: 0.0666
# Train Layer: 0, Epoch: 13/20, Iter: 600/600, Loss: 0.0656
# Train Layer: 0, Epoch: 14/20, Iter: 10/600, Loss: 0.0666
# Train Layer: 0, Epoch: 14/20, Iter: 20/600, Loss: 0.0660
# Train Layer: 0, Epoch: 14/20, Iter: 30/600, Loss: 0.0653
# Train Layer: 0, Epoch: 14/20, Iter: 40/600, Loss: 0.0674
# Train Layer: 0, Epoch: 14/20, Iter: 50/600, Loss: 0.0672
# Train Layer: 0, Epoch: 14/20, Iter: 60/600, Loss: 0.0694
# Train Layer: 0, Epoch: 14/20, Iter: 70/600, Loss: 0.0661
# Train Layer: 0, Epoch: 14/20, Iter: 80/600, Loss: 0.0686
# Train Layer: 0, Epoch: 14/20, Iter: 90/600, Loss: 0.0675
# Train Layer: 0, Epoch: 14/20, Iter: 100/600, Loss: 0.0705
# Train Layer: 0, Epoch: 14/20, Iter: 110/600, Loss: 0.0682
# Train Layer: 0, Epoch: 14/20, Iter: 120/600, Loss: 0.0701
# Train Layer: 0, Epoch: 14/20, Iter: 130/600, Loss: 0.0667
# Train Layer: 0, Epoch: 14/20, Iter: 140/600, Loss: 0.0670
# Train Layer: 0, Epoch: 14/20, Iter: 150/600, Loss: 0.0682
# Train Layer: 0, Epoch: 14/20, Iter: 160/600, Loss: 0.0696
# Train Layer: 0, Epoch: 14/20, Iter: 170/600, Loss: 0.0657
# Train Layer: 0, Epoch: 14/20, Iter: 180/600, Loss: 0.0683
# Train Layer: 0, Epoch: 14/20, Iter: 190/600, Loss: 0.0678
# Train Layer: 0, Epoch: 14/20, Iter: 200/600, Loss: 0.0675
# Train Layer: 0, Epoch: 14/20, Iter: 210/600, Loss: 0.0676
# Train Layer: 0, Epoch: 14/20, Iter: 220/600, Loss: 0.0681
# Train Layer: 0, Epoch: 14/20, Iter: 230/600, Loss: 0.0684
# Train Layer: 0, Epoch: 14/20, Iter: 240/600, Loss: 0.0666
# Train Layer: 0, Epoch: 14/20, Iter: 250/600, Loss: 0.0693
# Train Layer: 0, Epoch: 14/20, Iter: 260/600, Loss: 0.0690
# Train Layer: 0, Epoch: 14/20, Iter: 270/600, Loss: 0.0660
# Train Layer: 0, Epoch: 14/20, Iter: 280/600, Loss: 0.0655
# Train Layer: 0, Epoch: 14/20, Iter: 290/600, Loss: 0.0661
# Train Layer: 0, Epoch: 14/20, Iter: 300/600, Loss: 0.0658
# Train Layer: 0, Epoch: 14/20, Iter: 310/600, Loss: 0.0635
# Train Layer: 0, Epoch: 14/20, Iter: 320/600, Loss: 0.0672
# Train Layer: 0, Epoch: 14/20, Iter: 330/600, Loss: 0.0700
# Train Layer: 0, Epoch: 14/20, Iter: 340/600, Loss: 0.0692
# Train Layer: 0, Epoch: 14/20, Iter: 350/600, Loss: 0.0678
# Train Layer: 0, Epoch: 14/20, Iter: 360/600, Loss: 0.0686
# ...
# Train Layer: 0, Epoch: 18/20, Iter: 310/600, Loss: 0.0663
# Train Layer: 0, Epoch: 18/20, Iter: 320/600, Loss: 0.0665
# Train Layer: 0, Epoch: 18/20, Iter: 330/600, Loss: 0.0673
# Train Layer: 0, Epoch: 18/20, Iter: 340/600, Loss: 0.0643
# Train Layer: 0, Epoch: 18/20, Iter: 350/600, Loss: 0.0631
# Train Layer: 0, Epoch: 18/20, Iter: 360/600, Loss: 0.0669
# Train Layer: 0, Epoch: 18/20, Iter: 370/600, Loss: 0.0671
# Train Layer: 0, Epoch: 18/20, Iter: 380/600, Loss: 0.0637
# Train Layer: 0, Epoch: 18/20, Iter: 390/600, Loss: 0.0641
# Train Layer: 0, Epoch: 18/20, Iter: 400/600, Loss: 0.0652
# Train Layer: 0, Epoch: 18/20, Iter: 410/600, Loss: 0.0681
# Train Layer: 0, Epoch: 18/20, Iter: 420/600, Loss: 0.0632
# Train Layer: 0, Epoch: 18/20, Iter: 430/600, Loss: 0.0650
# Train Layer: 0, Epoch: 18/20, Iter: 440/600, Loss: 0.0651
# Train Layer: 0, Epoch: 18/20, Iter: 450/600, Loss: 0.0663
# Train Layer: 0, Epoch: 18/20, Iter: 460/600, Loss: 0.0654
# Train Layer: 0, Epoch: 18/20, Iter: 470/600, Loss: 0.0643
# Train Layer: 0, Epoch: 18/20, Iter: 480/600, Loss: 0.0659
# Train Layer: 0, Epoch: 18/20, Iter: 490/600, Loss: 0.0674
# Train Layer: 0, Epoch: 18/20, Iter: 500/600, Loss: 0.0667
# Train Layer: 0, Epoch: 18/20, Iter: 510/600, Loss: 0.0687
# Train Layer: 0, Epoch: 18/20, Iter: 520/600, Loss: 0.0638
# Train Layer: 0, Epoch: 18/20, Iter: 530/600, Loss: 0.0646
# Train Layer: 0, Epoch: 18/20, Iter: 540/600, Loss: 0.0661
# Train Layer: 0, Epoch: 18/20, Iter: 550/600, Loss: 0.0669
# Train Layer: 0, Epoch: 18/20, Iter: 560/600, Loss: 0.0659
# Train Layer: 0, Epoch: 18/20, Iter: 570/600, Loss: 0.0670
# Train Layer: 0, Epoch: 18/20, Iter: 580/600, Loss: 0.0704
# Train Layer: 0, Epoch: 18/20, Iter: 590/600, Loss: 0.0684
# Train Layer: 0, Epoch: 18/20, Iter: 600/600, Loss: 0.0677
# Train Layer: 0, Epoch: 19/20, Iter: 10/600, Loss: 0.0649
# Train Layer: 0, Epoch: 19/20, Iter: 20/600, Loss: 0.0670
# Train Layer: 0, Epoch: 19/20, Iter: 30/600, Loss: 0.0637
# Train Layer: 0, Epoch: 19/20, Iter: 40/600, Loss: 0.0661
# Train Layer: 0, Epoch: 19/20, Iter: 50/600, Loss: 0.0661
# Train Layer: 0, Epoch: 19/20, Iter: 60/600, Loss: 0.0680
# Train Layer: 0, Epoch: 19/20, Iter: 70/600, Loss: 0.0687
# Train Layer: 0, Epoch: 19/20, Iter: 80/600, Loss: 0.0676
# Train Layer: 0, Epoch: 19/20, Iter: 90/600, Loss: 0.0663
# Train Layer: 0, Epoch: 19/20, Iter: 100/600, Loss: 0.0656
# Train Layer: 0, Epoch: 19/20, Iter: 110/600, Loss: 0.0638
# Train Layer: 0, Epoch: 19/20, Iter: 120/600, Loss: 0.0654
# Train Layer: 0, Epoch: 19/20, Iter: 130/600, Loss: 0.0646
# Train Layer: 0, Epoch: 19/20, Iter: 140/600, Loss: 0.0649
# Train Layer: 0, Epoch: 19/20, Iter: 150/600, Loss: 0.0664
# Train Layer: 0, Epoch: 19/20, Iter: 160/600, Loss: 0.0652
# Train Layer: 0, Epoch: 19/20, Iter: 170/600, Loss: 0.0636
# Train Layer: 0, Epoch: 19/20, Iter: 180/600, Loss: 0.0647
# Train Layer: 0, Epoch: 19/20, Iter: 190/600, Loss: 0.0647
# Train Layer: 0, Epoch: 19/20, Iter: 200/600, Loss: 0.0657
# Train Layer: 0, Epoch: 19/20, Iter: 210/600, Loss: 0.0657
# Train Layer: 0, Epoch: 19/20, Iter: 220/600, Loss: 0.0666
# Train Layer: 0, Epoch: 19/20, Iter: 230/600, Loss: 0.0673
# Train Layer: 0, Epoch: 19/20, Iter: 240/600, Loss: 0.0662
# Train Layer: 0, Epoch: 19/20, Iter: 250/600, Loss: 0.0661
# Train Layer: 0, Epoch: 19/20, Iter: 260/600, Loss: 0.0651
# Train Layer: 0, Epoch: 19/20, Iter: 270/600, Loss: 0.0671
# Train Layer: 0, Epoch: 19/20, Iter: 280/600, Loss: 0.0657
# Train Layer: 0, Epoch: 19/20, Iter: 290/600, Loss: 0.0639
# Train Layer: 0, Epoch: 19/20, Iter: 300/600, Loss: 0.0642
# Train Layer: 0, Epoch: 19/20, Iter: 310/600, Loss: 0.0666
# Train Layer: 0, Epoch: 19/20, Iter: 320/600, Loss: 0.0646
# Train Layer: 0, Epoch: 19/20, Iter: 330/600, Loss: 0.0678
# Train Layer: 0, Epoch: 19/20, Iter: 340/600, Loss: 0.0666
# Train Layer: 0, Epoch: 19/20, Iter: 350/600, Loss: 0.0655
# Train Layer: 0, Epoch: 19/20, Iter: 360/600, Loss: 0.0657
# Train Layer: 0, Epoch: 19/20, Iter: 370/600, Loss: 0.0664
# Train Layer: 0, Epoch: 19/20, Iter: 380/600, Loss: 0.0665
# Train Layer: 0, Epoch: 19/20, Iter: 390/600, Loss: 0.0643
# Train Layer: 0, Epoch: 19/20, Iter: 400/600, Loss: 0.0681
# Train Layer: 0, Epoch: 19/20, Iter: 410/600, Loss: 0.0668
# Train Layer: 0, Epoch: 19/20, Iter: 420/600, Loss: 0.0654
# Train Layer: 0, Epoch: 19/20, Iter: 430/600, Loss: 0.0663
# Train Layer: 0, Epoch: 19/20, Iter: 440/600, Loss: 0.0680
# Train Layer: 0, Epoch: 19/20, Iter: 450/600, Loss: 0.0676
# Train Layer: 0, Epoch: 19/20, Iter: 460/600, Loss: 0.0635
# Train Layer: 0, Epoch: 19/20, Iter: 470/600, Loss: 0.0653
# Train Layer: 0, Epoch: 19/20, Iter: 480/600, Loss: 0.0659
# Train Layer: 0, Epoch: 19/20, Iter: 490/600, Loss: 0.0646
# Train Layer: 0, Epoch: 19/20, Iter: 500/600, Loss: 0.0641
# Train Layer: 0, Epoch: 19/20, Iter: 510/600, Loss: 0.0664
# Train Layer: 0, Epoch: 19/20, Iter: 520/600, Loss: 0.0629
# Train Layer: 0, Epoch: 19/20, Iter: 530/600, Loss: 0.0659
# Train Layer: 0, Epoch: 19/20, Iter: 540/600, Loss: 0.0670
# Train Layer: 0, Epoch: 19/20, Iter: 550/600, Loss: 0.0668
# Train Layer: 0, Epoch: 19/20, Iter: 560/600, Loss: 0.0649
# Train Layer: 0, Epoch: 19/20, Iter: 570/600, Loss: 0.0664
# Train Layer: 0, Epoch: 19/20, Iter: 580/600, Loss: 0.0649
# Train Layer: 0, Epoch: 19/20, Iter: 590/600, Loss: 0.0680
# Train Layer: 0, Epoch: 19/20, Iter: 600/600, Loss: 0.0673
# Train Layer: 0, Epoch: 20/20, Iter: 10/600, Loss: 0.0637
# Train Layer: 0, Epoch: 20/20, Iter: 20/600, Loss: 0.0664
# Train Layer: 0, Epoch: 20/20, Iter: 30/600, Loss: 0.0681
# Train Layer: 0, Epoch: 20/20, Iter: 40/600, Loss: 0.0669
# Train Layer: 0, Epoch: 20/20, Iter: 50/600, Loss: 0.0632
# Train Layer: 0, Epoch: 20/20, Iter: 60/600, Loss: 0.0659
# Train Layer: 0, Epoch: 20/20, Iter: 70/600, Loss: 0.0632
# Train Layer: 0, Epoch: 20/20, Iter: 80/600, Loss: 0.0669
# Train Layer: 0, Epoch: 20/20, Iter: 90/600, Loss: 0.0656
# Train Layer: 0, Epoch: 20/20, Iter: 100/600, Loss: 0.0664
# Train Layer: 0, Epoch: 20/20, Iter: 110/600, Loss: 0.0664
# Train Layer: 0, Epoch: 20/20, Iter: 120/600, Loss: 0.0680
# Train Layer: 0, Epoch: 20/20, Iter: 130/600, Loss: 0.0666
# Train Layer: 0, Epoch: 20/20, Iter: 140/600, Loss: 0.0679
# Train Layer: 0, Epoch: 20/20, Iter: 150/600, Loss: 0.0630
# Train Layer: 0, Epoch: 20/20, Iter: 160/600, Loss: 0.0658
# Train Layer: 0, Epoch: 20/20, Iter: 170/600, Loss: 0.0661
# Train Layer: 0, Epoch: 20/20, Iter: 180/600, Loss: 0.0639
# Train Layer: 0, Epoch: 20/20, Iter: 190/600, Loss: 0.0679
# Train Layer: 0, Epoch: 20/20, Iter: 200/600, Loss: 0.0650
# Train Layer: 0, Epoch: 20/20, Iter: 210/600, Loss: 0.0663
# Train Layer: 0, Epoch: 20/20, Iter: 220/600, Loss: 0.0655
# Train Layer: 0, Epoch: 20/20, Iter: 230/600, Loss: 0.0669
# Train Layer: 0, Epoch: 20/20, Iter: 240/600, Loss: 0.0640
# Train Layer: 0, Epoch: 20/20, Iter: 250/600, Loss: 0.0685
# Train Layer: 0, Epoch: 20/20, Iter: 260/600, Loss: 0.0672
# Train Layer: 0, Epoch: 20/20, Iter: 270/600, Loss: 0.0671
# Train Layer: 0, Epoch: 20/20, Iter: 280/600, Loss: 0.0644
# Train Layer: 0, Epoch: 20/20, Iter: 290/600, Loss: 0.0631
# Train Layer: 0, Epoch: 20/20, Iter: 300/600, Loss: 0.0659
# Train Layer: 0, Epoch: 20/20, Iter: 310/600, Loss: 0.0666
# Train Layer: 0, Epoch: 20/20, Iter: 320/600, Loss: 0.0669
# Train Layer: 0, Epoch: 20/20, Iter: 330/600, Loss: 0.0644
# Train Layer: 0, Epoch: 20/20, Iter: 340/600, Loss: 0.0671
# Train Layer: 0, Epoch: 20/20, Iter: 350/600, Loss: 0.0651
# Train Layer: 0, Epoch: 20/20, Iter: 360/600, Loss: 0.0661
# Train Layer: 0, Epoch: 20/20, Iter: 370/600, Loss: 0.0636
# Train Layer: 0, Epoch: 20/20, Iter: 380/600, Loss: 0.0633
# Train Layer: 0, Epoch: 20/20, Iter: 390/600, Loss: 0.0663
# Train Layer: 0, Epoch: 20/20, Iter: 400/600, Loss: 0.0667
# Train Layer: 0, Epoch: 20/20, Iter: 410/600, Loss: 0.0631
# Train Layer: 0, Epoch: 20/20, Iter: 420/600, Loss: 0.0642
# Train Layer: 0, Epoch: 20/20, Iter: 430/600, Loss: 0.0616
# Train Layer: 0, Epoch: 20/20, Iter: 440/600, Loss: 0.0657
# Train Layer: 0, Epoch: 20/20, Iter: 450/600, Loss: 0.0687
# Train Layer: 0, Epoch: 20/20, Iter: 460/600, Loss: 0.0680
# Train Layer: 0, Epoch: 20/20, Iter: 470/600, Loss: 0.0669
# Train Layer: 0, Epoch: 20/20, Iter: 480/600, Loss: 0.0659
# Train Layer: 0, Epoch: 20/20, Iter: 490/600, Loss: 0.0628
# Train Layer: 0, Epoch: 20/20, Iter: 500/600, Loss: 0.0681
# Train Layer: 0, Epoch: 20/20, Iter: 510/600, Loss: 0.0659
# Train Layer: 0, Epoch: 20/20, Iter: 520/600, Loss: 0.0641
# Train Layer: 0, Epoch: 20/20, Iter: 530/600, Loss: 0.0647
# Train Layer: 0, Epoch: 20/20, Iter: 540/600, Loss: 0.0665
# Train Layer: 0, Epoch: 20/20, Iter: 550/600, Loss: 0.0631
# Train Layer: 0, Epoch: 20/20, Iter: 560/600, Loss: 0.0663
# Train Layer: 0, Epoch: 20/20, Iter: 570/600, Loss: 0.0665
# Train Layer: 0, Epoch: 20/20, Iter: 580/600, Loss: 0.0650
# Train Layer: 0, Epoch: 20/20, Iter: 590/600, Loss: 0.0655
# Train Layer: 0, Epoch: 20/20, Iter: 600/600, Loss: 0.0655
# Train Layer: 1, Epoch: 1/20, Iter: 10/600, Loss: 0.6935
# Train Layer: 1, Epoch: 1/20, Iter: 20/600, Loss: 0.6923
# Train Layer: 1, Epoch: 1/20, Iter: 30/600, Loss: 0.6914
# Train Layer: 1, Epoch: 1/20, Iter: 40/600, Loss: 0.6910
# Train Layer: 1, Epoch: 1/20, Iter: 50/600, Loss: 0.6904
# Train Layer: 1, Epoch: 1/20, Iter: 60/600, Loss: 0.6902
# Train Layer: 1, Epoch: 1/20, Iter: 70/600, Loss: 0.6883
# Train Layer: 1, Epoch: 1/20, Iter: 80/600, Loss: 0.6878
# Train Layer: 1, Epoch: 1/20, Iter: 90/600, Loss: 0.6861
# Train Layer: 1, Epoch: 1/20, Iter: 100/600, Loss: 0.6835
# Train Layer: 1, Epoch: 1/20, Iter: 110/600, Loss: 0.6819
# Train Layer: 1, Epoch: 1/20, Iter: 120/600, Loss: 0.6804
# Train Layer: 1, Epoch: 1/20, Iter: 130/600, Loss: 0.6785
# Train Layer: 1, Epoch: 1/20, Iter: 140/600, Loss: 0.6770
# Train Layer: 1, Epoch: 1/20, Iter: 150/600, Loss: 0.6739
# Train Layer: 1, Epoch: 1/20, Iter: 160/600, Loss: 0.6727
# Train Layer: 1, Epoch: 1/20, Iter: 170/600, Loss: 0.6688
# Train Layer: 1, Epoch: 1/20, Iter: 180/600, Loss: 0.6665
# Train Layer: 1, Epoch: 1/20, Iter: 190/600, Loss: 0.6666
# Train Layer: 1, Epoch: 1/20, Iter: 200/600, Loss: 0.6645
# Train Layer: 1, Epoch: 1/20, Iter: 210/600, Loss: 0.6620
# Train Layer: 1, Epoch: 1/20, Iter: 220/600, Loss: 0.6595
# Train Layer: 1, Epoch: 1/20, Iter: 230/600, Loss: 0.6590
# Train Layer: 1, Epoch: 1/20, Iter: 240/600, Loss: 0.6579
# Train Layer: 1, Epoch: 1/20, Iter: 250/600, Loss: 0.6574
# Train Layer: 1, Epoch: 1/20, Iter: 260/600, Loss: 0.6558
# Train Layer: 1, Epoch: 1/20, Iter: 270/600, Loss: 0.6522
# Train Layer: 1, Epoch: 1/20, Iter: 280/600, Loss: 0.6486
# Train Layer: 1, Epoch: 1/20, Iter: 290/600, Loss: 0.6507
# Train Layer: 1, Epoch: 1/20, Iter: 300/600, Loss: 0.6533
# Train Layer: 1, Epoch: 1/20, Iter: 310/600, Loss: 0.6476
# Train Layer: 1, Epoch: 1/20, Iter: 320/600, Loss: 0.6463
# Train Layer: 1, Epoch: 1/20, Iter: 330/600, Loss: 0.6454
# Train Layer: 1, Epoch: 1/20, Iter: 340/600, Loss: 0.6478
# Train Layer: 1, Epoch: 1/20, Iter: 350/600, Loss: 0.6449
# Train Layer: 1, Epoch: 1/20, Iter: 360/600, Loss: 0.6415
# Train Layer: 1, Epoch: 1/20, Iter: 370/600, Loss: 0.6381
# Train Layer: 1, Epoch: 1/20, Iter: 380/600, Loss: 0.6407
# Train Layer: 1, Epoch: 1/20, Iter: 390/600, Loss: 0.6409
# Train Layer: 1, Epoch: 1/20, Iter: 400/600, Loss: 0.6404
# Train Layer: 1, Epoch: 1/20, Iter: 410/600, Loss: 0.6413
# Train Layer: 1, Epoch: 1/20, Iter: 420/600, Loss: 0.6407
# Train Layer: 1, Epoch: 1/20, Iter: 430/600, Loss: 0.6407
# Train Layer: 1, Epoch: 1/20, Iter: 440/600, Loss: 0.6400
# Train Layer: 1, Epoch: 1/20, Iter: 450/600, Loss: 0.6352
# Train Layer: 1, Epoch: 1/20, Iter: 460/600, Loss: 0.6328
# Train Layer: 1, Epoch: 1/20, Iter: 470/600, Loss: 0.6364
# Train Layer: 1, Epoch: 1/20, Iter: 480/600, Loss: 0.6354
# Train Layer: 1, Epoch: 1/20, Iter: 490/600, Loss: 0.6335
# Train Layer: 1, Epoch: 1/20, Iter: 500/600, Loss: 0.6330
# Train Layer: 1, Epoch: 1/20, Iter: 510/600, Loss: 0.6315
# Train Layer: 1, Epoch: 1/20, Iter: 520/600, Loss: 0.6316
# Train Layer: 1, Epoch: 1/20, Iter: 530/600, Loss: 0.6271
# Train Layer: 1, Epoch: 1/20, Iter: 540/600, Loss: 0.6262
# Train Layer: 1, Epoch: 1/20, Iter: 550/600, Loss: 0.6295
# Train Layer: 1, Epoch: 1/20, Iter: 560/600, Loss: 0.6254
# Train Layer: 1, Epoch: 1/20, Iter: 570/600, Loss: 0.6246
# Train Layer: 1, Epoch: 1/20, Iter: 580/600, Loss: 0.6253
# Train Layer: 1, Epoch: 1/20, Iter: 590/600, Loss: 0.6219
# Train Layer: 1, Epoch: 1/20, Iter: 600/600, Loss: 0.6266
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-e704372139f6> in <cell line: 21>()
#      20 # Pre-train each layer
#      21 for level in range(nun_layers - 1):
# ---> 22     train_layers(layers_list=layers_list, layer=level, epoch=num_tranin_layer_epochs, validate=True)
#      23
#      24 SAE_model_with_pretrain = StackedAutoEncoder(layers_list=layers_list)
#
# <ipython-input-14-98641cdf16b1> in train_layers(layers_list, layer, epoch, validate)
#      62             layers_list[layer].eval()
#      63             test_data = test_data.cuda() if torch.cuda.is_available() else test_data
# ---> 64             test_output = layers_list[layer](test_data.view(test_data.size(0), -1))
#      65             torchvision.utils.save_image(test_output.view(batch_size, 1, 28, 28), './test_images/pretrain_layer_{}_epoch_{}_output.png'.format(layer, epoch_index))
#      66
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-13-1f5e5f49a031> in forward(self, x)
#      23
#      24     def forward(self, x):
# ---> 25         out = self.encoder(x)
#      26         if self.is_training_self:
#      27             return self.decoder(out)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (100x784 and 256x64)

# %%
# SAE_model = StackedAutoEncoder(layers_list=layers_list)
# torch.save(SAE_model, './models/sae_model_layer.pt')

# torch.save(SAE_model, './sae_model.pt')

# %%
# You can later check the saved test images here
# !cd /root/test_images
# !ls

# %%
test_data, _ = next(iter(test_loader))
torchvision.utils.save_image(test_data, './test_images/real_test_images.png')

with torch.no_grad():
    SAE_model.eval()
    if torch.cuda.is_available():
        test_data = test_data.cuda()
    x = test_data.view(test_data.size(0), -1)
    out = SAE_model(x)
    loss = criterion(out, x)

    image_tensor = out.view(20, 1, 28, 28)
    torchvision.utils.save_image(image_tensor, './test_layer_images/manual_test.png')
